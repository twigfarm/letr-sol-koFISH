# %% [markdown]
# <a href="https://colab.research.google.com/github/2pterons/twigfarm/blob/main/%EB%B8%8C%EB%9F%B0%EC%B9%98%ED%81%AC%EB%A1%A4%EB%A7%81_%EA%B5%AC%EC%A1%B0%ED%99%95%EC%9D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from bs4 import BeautifulSoup

url = 'https://brunch.co.kr/keyword/%EC%A7%80%EA%B5%AC%ED%95%9C%EB%B0%94%ED%80%B4_%EC%84%B8%EA%B3%84%EC%97%AC%ED%96%89?q=g'

headers = {'users-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36'}

r = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(r.content, 'lxml')
div = soup.find('div', id='wrapArticle')
div
# Out:
# <div class="wrap_article" id="wrapArticle">
# <h4 class="screen_out">글 목록</h4>
# <div class="wrap_article_list #keyword_related_contents">
# <ul class="list_article list_common">
# </ul>
# <div class="layer-more-loading" id="loadSpinner" style="display: block;">
# <div class="loader">
# <div class="dot dot1"></div>
# <div class="dot dot2"></div>
# <div class="dot dot3"></div>
# </div>
# </div>
# </div>
# <div class="wrap_writer_list animation_up_late">
# <strong class="tit_recommend">추천작가</strong>
# <div class="search_recommend">
# <a class="item_recommend" data-tiara-action-name="키워드 콘텐츠 목록 &gt; 연관 작가 클릭" data-tiara-layer="related_writers" href="/@@1T6i" target="_blank">
# <span class="thumb_g">
# <img alt="이주강 알이즈웰전도사" class="img_thumb" height="36" src="//img1.daumcdn.net/thumb/C42x42.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/1T6i/image/WdtZyC57SoEWM-Qq_iSUKVLWX9g.jpeg" width="36"/>
# </span>
# <div class="detail_recommend">
# <div class="inner_recommend">
# <span class="txt_recommend">이주강 알이즈웰전도사</span>
# <span class="txt_info">
# <span class="txt_g">글 238</span>
# <span class="ico_dot"></span>
# <span class="txt_g">구독자 133</span>
# </span>
# </div>
# </div>
# </a>
# <a class="item_recommend" data-tiara-action-name="키워드 콘텐츠 목록 &gt; 연관 작가 클릭" data-tiara-layer="related_writers" href="/@@1bAk" target="_blank">
# <span class="thumb_g">
# <img alt="타이킴" class="img_thumb" height="36" src="//img1.daumcdn.net/thumb/C42x42.fjpg/?fname=http://t1.daumcdn.net/brunch/service/guest/image/Nf2CMLkY3x_EUD8HObGo4rPszeM" width="36"/>
# </span>
# <div class="detail_recommend">
# <div class="inner_recommend">
# <span class="txt_recommend">타이킴</span>
# <span class="txt_info">
# <span class="txt_g">글 70</span>
# <span class="ico_dot"></span>
# <span class="txt_g">구독자 87</span>
# </span>
# </div>
# </div>
# </a>
# <a class="item_recommend" data-tiara-action-name="키워드 콘텐츠 목록 &gt; 연관 작가 클릭" data-tiara-layer="related_writers" href="/@@1VN6" target="_blank">
# <span class="thumb_g">
# <img alt="리작가" class="img_thumb" height="36" src="//img1.daumcdn.net/thumb/C42x42.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/1VN6/image/AUAaErCmGRhrmz_ARRtBzSQhT-k.JPG" width="36"/>
# </span>
# <div class="detail_recommend">
# <div class="inner_recommend">
# <span class="txt_recommend">리작가</span>
# <span class="txt_info">
# <span class="txt_g">글 57</span>
# <span class="ico_dot"></span>
# <span class="txt_g">구독자 657</span>
# </span>
# </div>
# </div>
# </a>
# <a class="item_recommend" data-tiara-action-name="키워드 콘텐츠 목록 &gt; 연관 작가 클릭" data-tiara-layer="related_writers" href="/@@1czs" target="_blank">
# <span class="thumb_g">
# <img alt="조작가" class="img_thumb" height="36" src="//img1.daumcdn.net/thumb/C42x42.fjpg/?fname=http://t1.daumcdn.net/brunch/service/guest/image/icWw9EjuEF_0_Hq9gZWAB9XWUr4.jpg" width="36"/>
# </span>
# <div class="detail_recommend">
# <div class="inner_recommend">
# <span class="txt_recommend">조작가</span>
# <span class="txt_info">
# <span class="txt_g">글 66</span>
# <span class="ico_dot"></span>
# <span class="txt_g">구독자 54</span>
# </span>
# </div>
# </div>
# </a>
# <a class="item_recommend" data-tiara-action-name="키워드 콘텐츠 목록 &gt; 연관 작가 클릭" data-tiara-layer="related_writers" href="/@@1SPE" target="_blank">
# <span class="thumb_g">
# <img alt="치유김쟉" class="img_thumb" height="36" src="//img1.daumcdn.net/thumb/C42x42.fjpg/?fname=http://t1.daumcdn.net/brunch/service/user/1SPE/image/WzOCBPD2icQusDs3Yv2IP1OQVBY.jpg" width="36"/>
# </span>
# <div class="detail_recommend">
# <div class="inner_recommend">
# <span class="txt_recommend">치유김쟉</span>
# <span class="txt_info">
# <span class="txt_g">글 142</span>
# <span class="ico_dot"></span>
# <span class="txt_g">구독자 48</span>
# </span>
# </div>
# </div>
# </a>
# <a class="item_recommend" data-tiara-action-name="키워드 콘텐츠 목록 &gt; 연관 작가 클릭" data-tiara-layer="related_writers" href="/@@1Mxf" target="_blank">
# <span class="thumb_g">
# <img alt="지노킴" class="img_thumb" height="36" src="//img1.daumcdn.net/thumb/C42x42.fpng/?fname=http://t1.daumcdn.net/brunch/service/guest/image/5mvkeIlNWNKffmqykr9zlyg58TE.png" width="36"/>
# </span>
# <div class="detail_recommend">
# <div class="inner_recommend">
# <span class="txt_recommend">지노킴</span>
# <span class="txt_info">
# <span class="txt_g">글 344</span>
# <span class="ico_dot"></span>
# <span class="txt_g">구독자 1,935</span>
# </span>
# </div>
# </div>
# </a>
# </div>
# </div>
# </div>

# %%
import requests
import json
import time

publishTime = 1631457213000
pickContentId = '' 

for i in range(10): # 0~9

    params = {
        'publishTime': publishTime
    }

    response = requests.get("https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime=1631457213000&pickContentId=", params=params)
    data = json.loads(response.text)
print(data)
# Out:
# {'desc': 'OK', 'code': 200, 'title': '', 'extra': '', 'data': {'keyword': '지구한바퀴 세계여행', 'profileList': [{'userId': '1Mxf', 'userName': '지노킴', 'userImage': 'http://t1.daumcdn.net/brunch/service/guest/image/5mvkeIlNWNKffmqykr9zlyg58TE.png', 'profileId': 'jinhokim', 'profileImage': None, 'description': '미국 버지니아 비치에 살면서 세계 배낭여행자를 꿈꾸다.', 'createTime': 1460973439000, 'status': 'verify', 'articleCount': 344, 'socialUser': False, 'writerCount': 95, 'followerCount': 1935, 'magazineCount': 0, 'company': '', 'descriptionDetail': '', 'profileNotiExpireTime': 1624843959000, 'userSns': {'userId': '1Mxf', 'website': '', 'facebook': None, 'twitter': None, 'instagram': None, 'createTime': 1536451066000, 'updateTime': 1536451066000}, 'bookStoreBookList': [], 'profileCategoryList': None, 'mainProduct': None, 'acceptPropose': True, 'articleViewType': 'IMAGE', 'brunchActivityList': [], 'emailValidation': True, 'talkChannelProfile': None, 'articleViewCount': 0, 'userNameHighlight': None, 'descriptionHighlight': None, 'keywords': None, 'keywordsHighlight': None, 'myFollower': False, 'myWriter': False, 'restrictTime': None, 'author': True, 'talkChannelConnected': False, 'restrict0': False}, {'userId': '16iq', 'userName': '김중희', 'userImage': 'http://t1.daumcdn.net/brunch/service/user/16iq/image/YSxdEMpQj_jBTAlDVbpY9vk69b0', 'profileId': 'joongheekim', 'profileImage': None, 'description': '남편 ,아이셋,강아지 한마리 와의 작고 소소한 독일 일상을 글로 녹여 냅니다.우리의 평범한 이야기가 누군가의 입가에 잔잔한 미소로 머물기를 바래봅니다.', 'createTime': 1453134356000, 'status': 'verify', 'articleCount': 554, 'socialUser': False, 'writerCount': 1, 'followerCount': 4839, 'magazineCount': 0, 'company': '', 'descriptionDetail': '', 'profileNotiExpireTime': 1631466981000, 'userSns': {'userId': '16iq', 'website': '', 'facebook': None, 'twitter': None, 'instagram': None, 'createTime': 1533286636000, 'updateTime': 1600755562000}, 'bookStoreBookList': [], 'profileCategoryList': None, 'mainProduct': None, 'acceptPropose': True, 'articleViewType': 'TEXT', 'brunchActivityList': [], 'emailValidation': True, 'talkChannelProfile': None, 'articleViewCount': 0, 'userNameHighlight': None, 'descriptionHighlight': None, 'keywords': None, 'keywordsHighlight': None, 'myFollower': False, 'myWriter': False, 'restrictTime': None, 'author': True, 'talkChannelConnected': False, 'restrict0': False}, {'userId': '1U7Q', 'userName': '이지', 'userImage': 'http://t1.daumcdn.net/brunch/service/user/1U7Q/image/tKE9GmzYNAe9v-V4XYWSECadU6I.png', 'profileId': 'jongsa', 'profileImage': None, 'description': '여행을 통해 깨달은 삶의 지혜를 전달합니다.', 'createTime': 1462077012000, 'status': 'verify', 'articleCount': 32, 'socialUser': False, 'writerCount': 37, 'followerCount': 28, 'magazineCount': 0, 'company': '', 'descriptionDetail': '', 'profileNotiExpireTime': 1613318681000, 'userSns': {'userId': '1U7Q', 'website': '', 'facebook': None, 'twitter': None, 'instagram': None, 'createTime': 1607173480000, 'updateTime': 1607173480000}, 'bookStoreBookList': [], 'profileCategoryList': None, 'mainProduct': None, 'acceptPropose': True, 'articleViewType': 'IMAGE', 'brunchActivityList': [], 'emailValidation': True, 'talkChannelProfile': {'no': 2055, 'userId': '1U7Q', 'name': '이지의 세계여행', 'uuid': '@jongsa', 'profileImageUrl': 'http://k.kakaocdn.net/dn/bKP2D5/btrd0jfQkRs/3E0KB8H8XZL7b4JM4Uv671/img_xl.jpg', 'appScheme': 'kakaoplus://plusfriend/home/@jongsa?default_tab=creatorCenter', 'createTime': 1630744898000, 'updateTime': 1631227678000, 'disabled': False, 'autoConnected': False}, 'articleViewCount': 0, 'userNameHighlight': None, 'descriptionHighlight': None, 'keywords': None, 'keywordsHighlight': None, 'myFollower': False, 'myWriter': False, 'restrictTime': None, 'author': True, 'talkChannelConnected': True, 'restrict0': False}, {'userId': '1Ujz', 'userName': '정재은', 'userImage': 'http://t1.daumcdn.net/brunch/service/user/1Ujz/image/z13UjBqkjLtyWkl9P0Kla3vuEe4.JPG', 'profileId': 'jaeun1230', 'profileImage': None, 'description': '한국과 독일에서 6년간 축구 현장을 누볐습니다. 뮌헨살이 4년 차, 분데스리가 및 독일 일상 이야기를  ...

# %%
    test = data['data']
    test['articleList']

    for d in test['articleList']:
    print(d['contentSummary'])

    publishTime = data['publishTime']

    time.sleep(1)

# %%
test = data['data']
test
# Out:
# {'articleList': [{'article': {'arrivedLikeitCount': 0,
#     'articleCoverColorForHome': None,
#     'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/t_LbPTgePUCb2WuuRE4YP-QHP0Y.jpg',
#     'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/t_LbPTgePUCb2WuuRE4YP-QHP0Y.jpg',
#     'articleImageList': [{'articleNo': 67,
#       'height': 1920,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/t_LbPTgePUCb2WuuRE4YP-QHP0Y.jpg',
#       'userId': 'aiNt',
#       'width': 1080},
#      {'articleNo': 67,
#       'height': 960,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 2,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/l7u4Lk_QnWPx9aEqJL2OvzgqB3A.JPG',
#       'userId': 'aiNt',
#       'width': 1280},
#      {'articleNo': 67,
#       'height': 959,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 3,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/36cYohlY6_tUXfC6WgQRqKvclis.JPG',
#       'userId': 'aiNt',
#       'width': 1280},
#      {'articleNo': 67,
#       'height': 1706,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 4,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/Z9mkawYUCGhrkJWP_y-oIFA3f_Q.JPG',
#       'userId': 'aiNt',
#       'width': 1280},
#      {'articleNo': 67,
#       'height': 1679,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 5,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/qeWiSiqMd5CZvFBXkEKNK4pxQLY.jpg',
#       'userId': 'aiNt',
#       'width': 1080},
#      {'articleNo': 67,
#       'height': 2286,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 6,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/p0uabcNHSywPJvq3udQRjBhtO7k.JPG',
#       'userId': 'aiNt',
#       'width': 3048}],
#     'articleImageListForHome': [{'articleNo': 67,
#       'height': 1920,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/t_LbPTgePUCb2WuuRE4YP-QHP0Y.jpg',
#       'userId': 'aiNt',
#       'width': 1080}],
#     'articleKeywordNameAsCsv': None,
#     'articleKeywordNoAsCsv': None,
#     'articleKeywords': None,
#     'authorComment': '작가의 한마디가 나옵니다.',
#     'chapterNo': 0,
#     'commentCount': 0,
#     'commentWritable': True,
#     'content': None,
#     'contentHash': 'c42a9816c23e2a9bffede47272f7bf155661fed6',
#     'contentId': 'aiNt_67',
#     'contentIdParam': None,
#     'contentSummary': '캐나다 건국 150주년을 맞이한 축하행사가 있다고 해서 거기에 가기로 했다. 미리엄과 나는 엷은 화장을 하고 파라솔까지 들고 길을 나섰다. 지나가는 차 안에서 보는 사람들이 저 여자들은 뭐지 하면서 쳐다볼 거라고, 우린 우리 모습을 자평하며 낄낄거렸다. 이곳 사람들은 화장은 고사하고, 집에서 입던 옷 그대로 입고 나와 돌아다니는\xa0것 같다. 남자고 여자고, ',
#     'coverColor': None,
#     'coverInfo': None,
#     'createTime': 1631374252000,
#     'facebookShareCount': 0,
#     'flattenedSeq': 0,
#     'fromTime': None,
#     'homeDataSourceType': None,
#     'id': None,
#     'kakaoShareCount': 0,
#     'kakaoTalkShareCount': 0,
#     'likeCount': 9,
#     'magazineAddress': None,
#     'magazineAddressUri': None,
#     'magazineArticle': False,
#     'magazineArticleId': 0,
#     'magazineCoverImage': None,
#     'magazineNo': 0,
#     'magazineStatus': None,
#     'magazineTitle': None,
#     'magazineType': None,
#     'no': 67,
#     'nonMagazineArticle': True,
#     'notEmptyTitle': True,
#     'notPublished': False,
#     'orderBy': None,
#     'pick': False,
#     'profileId': 'rlrmadks',
#     'publishTime': 1631456088000,
#     'publishTimestamp': 1631456088515,
#     'published': True,
#     'readSeconds': 186,
#     'readTime': 0,
#     'restrictTime': None,
#     'seq': 0,
#     'socialShareTotalCount': 0,
#     'status': 'publish',
#     'subTitle': '- 캐나다의 불꽃놀이',
#     'tempBrunchbookAddress': None,
#     'tempBrunchbookNo': 0,
#     'tempBrunchbookStatus': None,
#     'tempBrunchbookTitle': None,
#     'title': '나와는 참 다른 여자들, 미리엄과 미셸린',
#     'toTime': None,
#     'twitterShareCount': 0,
#     'updateTime': 1631534646000,
#     'userId': 'aiNt',
#     'userName': None,
#     'version': None,
#     'viewCount': 0},
#    'profile': {'acceptPropose': True,
#     'articleCount': 55,
#     'articleViewType': 'TEXT',
#     'author': True,
#     'bookStoreBookList': [],
#     'brunchActivityList': [],
#     'company': '',
#     'createTime': 1591157235000,
#     'description': '퇴직후 14개 국을 여행하고 그것을 여행기로 묶어내는 중이다. 여행은 계속될 것이다.',
#     'descriptionDetail': '',
#     'emailValidation': True,
#     'followerCount': 7,
#     'magazineCount': 0,
#     'mainProduct': None,
#     'profileCategoryList': [{'category': 'subject',
#       'categoryName': '주제',
#       'categoryNo': 1,
#       'keywordList': [{'frequency': None,
#         'keyword': '여행',
#         'keywordNo': 2299,
#         'no': 33,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '글쓰기',
#         'keywordNo': 808,
#         'no': 9,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '라이프스타일',
#         'keywordNo': 1167,
#         'no': 14,
#         'sequence': 2}]},
#      {'category': 'job',
#       'categoryName': '직업',
#       'categoryNo': 2,
#       'keywordList': [{'frequency': None,
#         'keyword': '작가지망생',
#         'keywordNo': 101608,
#         'no': 101,
#         'sequence': 0}]}],
#     'profileId': 'rlrmadks',
#     'profileImage': None,
#     'profileNotiExpireTime': 1630728810000,
#     'restrict0': False,
#     'restrictTime': None,
#     'socialUser': False,
#     'status': 'verify',
#     'talkChannelConnected': False,
#     'talkChannelProfile': None,
#     'userId': 'aiNt',
#     'userImage': 'http://t1.daumcdn.net/brunch/service/user/aiNt/image/JtBmPTFft_Ns2_eKIqONXVN95vM.jpg',
#     'userName': 'Annie',
#     'userSns': {'createTime': 1630058241000,
#      'facebook': None,
#      'instagram': None,
#      'twitter': None,
#      'updateTime': 1630058241000,
#      'userId': 'aiNt',
#      'website': ''},
#     'writerCount': 7},
#    'timestamp': 1631456088000},
#   {'article': {'arrivedLikeitCount': 10,
#     'articleCoverColorForHome': None,
#     'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/a98DKcaqZ9EotJqXeuQAC-dW6ZI.jpg',
#     'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/a98DKcaqZ9EotJqXeuQAC-dW6ZI.jpg',
#     'articleImageList': [{'articleNo': 6,
#       'height': 2592,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/a98DKcaqZ9EotJqXeuQAC-dW6ZI.jpg',
#       'userId': '4ObX',
#       'width': 1936},
#      {'articleNo': 6,
#       'height': 1276,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 2,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/uVmzpjRaz6m_wKvog8kFBy0uFs8.jpg',
#       'userId': '4ObX',
#       'width': 1920},
#      {'articleNo': 6,
#       'height': 2672,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 3,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/Oo8LMGYaoKfm3RXKUYJSpY8rb3c.JPG',
#       'userId': '4ObX',
#       'width': 4000},
#      {'articleNo': 6,
#       'height': 2672,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 4,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/DbnB3QpJ90-FezcjpClSirmQMyY.JPG',
#       'userId': '4ObX',
#       'width': 4000},
#      {'articleNo': 6,
#       'height': 4000,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 5,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/Y4SWBzYr8f-fXP5-dOsX1b0qRAw.JPG',
#       'userId': '4ObX',
#       'width': 2672},
#      {'articleNo': 6,
#       'height': 2592,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 6,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/LPgY2Y3Q7zb9p9KMvIJnhmBZs7I.jpg',
#       'userId': '4ObX',
#       'width': 1936},
#      {'articleNo': 6,
#       'height': 2592,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 7,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/ZTnHXTtOd9mnkKpOvavtjOorHxA.JPG',
#       'userId': '4ObX',
#       'width': 1936},
#      {'articleNo': 6,
#       'height': 3254,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 8,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/guest/image/y8aEWYCgZEmtqQNgopJbm7fOjmw.jpg',
#       'userId': '4ObX',
#       'width': 2134},
#      {'articleNo': 6,
#       'height': 1880,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 9,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/adnoQQdSOgilFeGY5LmsjA2tO1U.JPG',
#       'userId': '4ObX',
#       'width': 2816},
#      {'articleNo': 6,
#       'height': 338,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 10,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/guest/image/Zoeo1Y5oY0cQkhpQBBOwdnhhZM8.JPG',
#       'userId': '4ObX',
#       'width': 600},
#      {'articleNo': 6,
#       'height': 1704,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 11,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/7zqopvsGJkMxDHYoylsgQlGwWaE.jpg',
#       'userId': '4ObX',
#       'width': 2272},
#      {'articleNo': 6,
#       'height': 1936,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 12,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/6tCRZQsfPJOn7qXw4P_DAdpI9UU.JPG',
#       'userId': '4ObX',
#       'width': 2592},
#      {'articleNo': 6,
#       'height': 2560,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 13,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/WYlEBu5R1zcVh6vI8LFcr5Wr6HY.JPG',
#       'userId': '4ObX',
#       'width': 1920},
#      {'articleNo': 6,
#       'height': 3648,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 14,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/KLgfu-tS2UFrjtkZudCNI5CoUCs.JPG',
#       'userId': '4ObX',
#       'width': 5472},
#      {'articleNo': 6,
#       'height': 3648,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 15,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/EVFo7yNsAAcGpL7wY1I_E9mOq78.JPG',
#       'userId': '4ObX',
#       'width': 5472},
#      {'articleNo': 6,
#       'height': 1280,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 16,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/ZsPmmqIhmComMGnKOTuVxCvCdvg.jpg',
#       'userId': '4ObX',
#       'width': 1920},
#      {'articleNo': 6,
#       'height': 3086,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 17,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/hjpjnGGHHJqlBmqGkIoO4xebEAE.jpg',
#       'userId': '4ObX',
#       'width': 2491},
#      {'articleNo': 6,
#       'height': 2672,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 18,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/h9CiLCF-5x5Iv3ddaZP9LZMlINY.JPG',
#       'userId': '4ObX',
#       'width': 4000},
#      {'articleNo': 6,
#       'height': 2672,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 19,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/bSObsJC0PW3eKEKdYkIEnMpN-J4.JPG',
#       'userId': '4ObX',
#       'width': 4000},
#      {'articleNo': 6,
#       'height': 684,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 20,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/guest/image/D2sAJ4kQqkRl6lE6aRJbXQC7rvY.jpg',
#       'userId': '4ObX',
#       'width': 1024},
#      {'articleNo': 6,
#       'height': 715,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 21,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/RJW9wUnN7aKoVhrg-HNvaXmhwNI.png',
#       'userId': '4ObX',
#       'width': 640},
#      {'articleNo': 6,
#       'height': 1920,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 22,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/WpN9-5wzJmM7AKEwTuOYs-OisH0.JPG',
#       'userId': '4ObX',
#       'width': 2560},
#      {'articleNo': 6,
#       'height': 1920,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 23,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/02ApSYT7KbbEHA-K-4aePZnCEqg.JPG',
#       'userId': '4ObX',
#       'width': 2560},
#      {'articleNo': 6,
#       'height': 1920,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 24,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/LnFnRD7i6MH6q_5wtH0OE_svi2Q.JPG',
#       'userId': '4ObX',
#       'width': 2560},
#      {'articleNo': 6,
#       'height': 1920,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 25,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/DUL4DW59ogF505h2P9IL6IHiIDA.JPG',
#       'userId': '4ObX',
#       'width': 2560}],
#     'articleImageListForHome': [{'articleNo': 6,
#       'height': 2592,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/a98DKcaqZ9EotJqXeuQAC-dW6ZI.jpg',
#       'userId': '4ObX',
#       'width': 1936}],
#     'articleKeywordNameAsCsv': None,
#     'articleKeywordNoAsCsv': None,
#     'articleKeywords': None,
#     'authorComment': '작가의 한마디가 나옵니다.',
#     'chapterNo': 0,
#     'commentCount': 1,
#     'commentWritable': True,
#     'content': None,
#     'contentHash': '73857f910a9b2c28c1a7a845d5937d3eaad11778',
#     'contentId': '4ObX_6',
#     'contentIdParam': None,
#     'contentSummary': '나는 호기심이 왕성한 인간이다. 호기심이 있어야만 여행도 식도락도 다채롭게 즐길 수 있다고 생각한다. 아니, 좀 거창하게 말하면 생물의 진화를 가능케 한 것도 호기심이다. 원시 해양을 헤엄치며 살아가던 폐어(肺魚) 중 호기심 많은 녀석들 덕택에 고생대에 육상 동물이 출현할 수 있었다, 고 주장하는 건 오버일까? 호모 사피엔스로 한정하자면 호기심 넘치는 몇몇',
#     'coverColor': None,
#     'coverInfo': None,
#     'createTime': 1631448997000,
#     'facebookShareCount': 0,
#     'flattenedSeq': 0,
#     'fromTime': None,
#     'homeDataSourceType': None,
#     'id': None,
#     'kakaoShareCount': 0,
#     'kakaoTalkShareCount': 0,
#     'likeCount': 13,
#     'magazineAddress': None,
#     'magazineAddressUri': None,
#     'magazineArticle': False,
#     'magazineArticleId': 0,
#     'magazineCoverImage': None,
#     'magazineNo': 0,
#     'magazineStatus': None,
#     'magazineTitle': None,
#     'magazineType': None,
#     'no': 6,
#     'nonMagazineArticle': True,
#     'notEmptyTitle': True,
#     'notPublished': False,
#     'orderBy': None,
#     'pick': False,
#     'profileId': 'sanches',
#     'publishTime': 1631456033000,
#     'publishTimestamp': 1631456033243,
#     'published': True,
#     'readSeconds': 414,
#     'readTime': 0,
#     'restrictTime': None,
#     'seq': 0,
#     'socialShareTotalCount': 0,
#     'status': 'publish',
#     'subTitle': '그곳에서만 먹을 수 있는 신기한 식재료',
#     'tempBrunchbookAddress': None,
#     'tempBrunchbookNo': 0,
#     'tempBrunchbookStatus': None,
#     'tempBrunchbookTitle': None,
#     'title': '세계, 어디까지 먹어봤니?',
#     'toTime': None,
#     'twitterShareCount': 0,
#     'updateTime': 1631541661000,
#     'userId': '4ObX',
#     'userName': None,
#     'version': None,
#     'viewCount': 0},
#    'profile': {'acceptPropose': True,
#     'articleCount': 6,
#     'articleViewType': 'TEXT',
#     'author': True,
#     'bookStoreBookList': [],
#     'brunchActivityList': [],
#     'company': '',
#     'createTime': 1513492756000,
#     'description': '세상사 궁금하다보니 여행을 좋아합니다. 미천한 여행 경험을 뼈대 삼아, 그리고 여러 관심사를 바탕으로 세계에 관한 솔직하고 담백하며 잡다한 이야기를 할 것 같습니다.',
#     'descriptionDetail': '',
#     'emailValidation': True,
#     'followerCount': 10,
#     'magazineCount': 0,
#     'mainProduct': None,
#     'profileCategoryList': [{'category': 'subject',
#       'categoryName': '주제',
#       'categoryNo': 1,
#       'keywordList': [{'frequency': None,
#         'keyword': '여행',
#         'keywordNo': 2299,
#         'no': 33,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '콘텐츠',
#         'keywordNo': 3172,
#         'no': 58,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '창작',
#         'keywordNo': 2982,
#         'no': 53,
#         'sequence': 2}]},
#      {'category': 'job',
#       'categoryName': '직업',
#       'categoryNo': 2,
#       'keywordList': [{'frequency': None,
#         'keyword': '프로듀서',
#         'keywordNo': 3400,
#         'no': 111,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '언론인',
#         'keywordNo': 2253,
#         'no': 94,
#         'sequence': 1}]}],
#     'profileId': 'sanches',
#     'profileImage': None,
#     'profileNotiExpireTime': 1632147747000,
#     'restrict0': False,
#     'restrictTime': None,
#     'socialUser': False,
#     'status': 'verify',
#     'talkChannelConnected': False,
#     'talkChannelProfile': None,
#     'userId': '4ObX',
#     'userImage': 'http://t1.daumcdn.net/brunch/service/user/4ObX/image/mpVO_8uwAThBXGCzInXPhS7qFAE.JPG',
#     'userName': '산체스',
#     'userSns': {'createTime': 1628086261000,
#      'facebook': None,
#      'instagram': None,
#      'twitter': None,
#      'updateTime': 1628086261000,
#      'userId': '4ObX',
#      'website': ''},
#     'writerCount': 5},
#    'timestamp': 1631456033000},
#   {'article': {'arrivedLikeitCount': 10,
#     'articleCoverColorForHome': None,
#     'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/85bw/image/sHH0JKVZQ-8x0hEBGvBpe00fF3c.png',
#     'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/85bw/image/sHH0JKVZQ-8x0hEBGvBpe00fF3c.png',
#     'articleImageList': [{'articleNo': 22,
#       'height': 2048,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/85bw/image/sHH0JKVZQ-8x0hEBGvBpe00fF3c.png',
#       'userId': '85bw',
#       'width': 1536}],
#     'articleImageListForHome': [{'articleNo': 22,
#       'height': 2048,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/85bw/image/sHH0JKVZQ-8x0hEBGvBpe00fF3c.png',
#       'userId': '85bw',
#       'width': 1536}],
#     'articleKeywordNameAsCsv': None,
#     'articleKeywordNoAsCsv': None,
#     'articleKeywords': None,
#     'authorComment': '작가의 한마디가 나옵니다.',
#     'chapterNo': 0,
#     'commentCount': 0,
#     'commentWritable': True,
#     'content': None,
#     'contentHash': 'ffe7e9206351aee8f2ac9fa608119c26a629e206',
#     'contentId': '85bw_22',
#     'contentIdParam': None,
#     'contentSummary': '2003년은 싱가포르에 처음 와서 둥지를 튼 해이다. 덥고 습하다는 사전 지식대로 날씨는 그야말로 고온다습했다. 잠깐 외출을 하고 와도 아이들의 옷이 땀으로 흠뻑 젖었다. 땀구멍이 막혔던 내 몸도 수문을 급속도로 열기 시작했다. 가급적이면 외출을 삼가고 실내에서 에어컨을 켜고 지냈다. 한국의 겨울에 문을 닫고 보일러를 켜듯이 여기서는 시원한 온도를 유지하기',
#     'coverColor': None,
#     'coverInfo': None,
#     'createTime': 1628941244000,
#     'facebookShareCount': 0,
#     'flattenedSeq': 0,
#     'fromTime': None,
#     'homeDataSourceType': None,
#     'id': None,
#     'kakaoShareCount': 0,
#     'kakaoTalkShareCount': 0,
#     'likeCount': 12,
#     'magazineAddress': None,
#     'magazineAddressUri': None,
#     'magazineArticle': False,
#     'magazineArticleId': 0,
#     'magazineCoverImage': None,
#     'magazineNo': 0,
#     'magazineStatus': None,
#     'magazineTitle': None,
#     'magazineType': None,
#     'no': 22,
#     'nonMagazineArticle': True,
#     'notEmptyTitle': True,
#     'notPublished': False,
#     'orderBy': None,
#     'pick': False,
#     'profileId': 'kumhyejung',
#     'publishTime': 1631455554000,
#     'publishTimestamp': 1631455554114,
#     'published': True,
#     'readSeconds': 115,
#     'readTime': 0,
#     'restrictTime': None,
#     'seq': 0,
#     'socialShareTotalCount': 0,
#     'status': 'publish',
#     'subTitle': '3. 사스와 코로나',
#     'tempBrunchbookAddress': None,
#     'tempBrunchbookNo': 0,
#     'tempBrunchbookStatus': None,
#     'tempBrunchbookTitle': None,
#     'title': '열대우림의 시점',
#     'toTime': None,
#     'twitterShareCount': 0,
#     'updateTime': 1631534650000,
#     'userId': '85bw',
#     'userName': None,
#     'version': None,
#     'viewCount': 0},
#    'profile': {'acceptPropose': True,
#     'articleCount': 3,
#     'articleViewType': 'TEXT',
#     'author': True,
#     'bookStoreBookList': [],
#     'brunchActivityList': [],
#     'company': '',
#     'createTime': 1564418755000,
#     'description': '싱가포르에 거주합니다. 시간과 공간의 흔적을 글과 사진으로 남깁니다. 글을 쓰며 인생을 돌아 봅니다.',
#     'descriptionDetail': '‘싱가포르 꽃이 들려준 한국 시’출간',
#     'emailValidation': True,
#     'followerCount': 0,
#     'magazineCount': 0,
#     'mainProduct': None,
#     'profileCategoryList': [{'category': 'subject',
#       'categoryName': '주제',
#       'categoryNo': 1,
#       'keywordList': [{'frequency': None,
#         'keyword': '에세이',
#         'keywordNo': 2265,
#         'no': 32,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '여행',
#         'keywordNo': 2299,
#         'no': 33,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '해외생활',
#         'keywordNo': 3533,
#         'no': 60,
#         'sequence': 2}]},
#      {'category': 'job',
#       'categoryName': '직업',
#       'categoryNo': 2,
#       'keywordList': [{'frequency': None,
#         'keyword': '크리에이터',
#         'keywordNo': 18282,
#         'no': 108,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '프리랜서',
#         'keywordNo': 3410,
#         'no': 112,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '에세이스트',
#         'keywordNo': 128924,
#         'no': 96,
#         'sequence': 2}]}],
#     'profileId': 'kumhyejung',
#     'profileImage': None,
#     'profileNotiExpireTime': 1631093372000,
#     'restrict0': False,
#     'restrictTime': None,
#     'socialUser': False,
#     'status': 'verify',
#     'talkChannelConnected': True,
#     'talkChannelProfile': {'appScheme': 'kakaoplus://plusfriend/home/@kumhyejung?default_tab=creatorCenter',
#      'autoConnected': True,
#      'createTime': None,
#      'disabled': False,
#      'name': '금혜정',
#      'no': 0,
#      'profileImageUrl': 'http://k.kakaocdn.net/dn/hSOo0/btqwDoJujXa/8KpMyb7PuP7gDW5ouAKT2K/img_xl.jpg',
#      'updateTime': None,
#      'userId': '85bw',
#      'uuid': '@kumhyejung'},
#     'userId': '85bw',
#     'userImage': 'http://t1.daumcdn.net/brunch/service/user/85bw/image/PAnQXTFh-yt-OFPz5j9MfHZirP0.png',
#     'userName': '금혜정',
#     'userSns': {'createTime': 1630488572000,
#      'facebook': None,
#      'instagram': None,
#      'twitter': None,
#      'updateTime': 1630488572000,
#      'userId': '85bw',
#      'website': ''},
#     'writerCount': 1},
#    'timestamp': 1631455554000},
#   {'article': {'arrivedLikeitCount': 10,
#     'articleCoverColorForHome': None,
#     'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/cFSs/image/0xwcLoATY0CYT-bROKggDQ925WM.jpg',
#     'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/cFSs/image/0xwcLoATY0CYT-bROKggDQ925WM.jpg',
#     'articleImageList': [{'articleNo': 12,
#       'height': 652,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/cFSs/image/0xwcLoATY0CYT-bROKggDQ925WM.jpg',
#       'userId': 'cFSs',
#       'width': 1013},
#      {'articleNo': 12,
#       'height': 2448,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 2,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/cFSs/image/ozPHHmrqsIQzqbpSgHXagkj-Gq0.JPG',
#       'userId': 'cFSs',
#       'width': 2448},
#      {'articleNo': 12,
#       'height': 1241,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 3,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/cFSs/image/CkaAl3WNenLNwjt33w327oqkrsU.JPG',
#       'userId': 'cFSs',
#       'width': 1241}],
#     'articleImageListForHome': [{'articleNo': 12,
#       'height': 652,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/cFSs/image/0xwcLoATY0CYT-bROKggDQ925WM.jpg',
#       'userId': 'cFSs',
#       'width': 1013}],
#     'articleKeywordNameAsCsv': None,
#     'articleKeywordNoAsCsv': None,
#     'articleKeywords': None,
#     'authorComment': '작가의 한마디가 나옵니다.',
#     'chapterNo': 0,
#     'commentCount': 0,
#     'commentWritable': True,
#     'content': None,
#     'contentHash': 'b933c78896bbcbf538d7a24dade80d5b763109de',
#     'contentId': 'cFSs_12',
#     'contentIdParam': None,
#     'contentSummary': '여행은 낯선 곳에서 현실의 삶을 잊는 데서 시작한다. 발길이 익숙하지 못한 옆동네 산책도 여행이 된다. 비록 삭막한 시멘트 건물이 미관을 해쳐도, 뻔한 나무들이 조경으로 가꾸어져 있어도, 낯선 동선만으로도 소박한 탐험가의 기분을 느낀다. 하지만 그 어떤 관광명소도 내 생활터전이 되기 시작하면 그곳은 더 이상 여행지가 아니다.   만학(?)의 희망을 안고 도',
#     'coverColor': None,
#     'coverInfo': None,
#     'createTime': 1631455514000,
#     'facebookShareCount': 0,
#     'flattenedSeq': 0,
#     'fromTime': None,
#     'homeDataSourceType': None,
#     'id': None,
#     'kakaoShareCount': 0,
#     'kakaoTalkShareCount': 0,
#     'likeCount': 14,
#     'magazineAddress': 'randonnee',
#     'magazineAddressUri': '/magazine/randonnee',
#     'magazineArticle': True,
#     'magazineArticleId': 0,
#     'magazineCoverImage': None,
#     'magazineNo': 114674,
#     'magazineStatus': 'publish',
#     'magazineTitle': '걸어야 보이는 풍경들',
#     'magazineType': None,
#     'no': 12,
#     'nonMagazineArticle': False,
#     'notEmptyTitle': True,
#     'notPublished': False,
#     'orderBy': None,
#     'pick': False,
#     'profileId': 'lypsone',
#     'publishTime': 1631455514000,
#     'publishTimestamp': 1631455514129,
#     'published': True,
#     'readSeconds': 166,
#     'readTime': 0,
#     'restrictTime': None,
#     'seq': 0,
#     'socialShareTotalCount': 0,
#     'status': 'publish',
#     'subTitle': '다시 여행자로...',
#     'tempBrunchbookAddress': None,
#     'tempBrunchbookNo': 0,
#     'tempBrunchbookStatus': None,
#     'tempBrunchbookTitle': None,
#     'title': '파리병을 극복한 것 같다',
#     'toTime': None,
#     'twitterShareCount': 0,
#     'updateTime': 1631534652000,
#     'userId': 'cFSs',
#     'userName': None,
#     'version': None,
#     'viewCount': 0},
#    'profile': {'acceptPropose': True,
#     'articleCount': 12,
#     'articleViewType': 'TEXT',
#     'author': True,
#     'bookStoreBookList': [],
#     'brunchActivityList': [],
#     'company': '',
#     'createTime': 1624719942000,
#     'description': '파리에 거주 중인 주변인. 탈경계를 꿈꾸며 읽고 씁니다.',
#     'descriptionDetail': '',
#     'emailValidation': True,
#     'followerCount': 6,
#     'magazineCount': 2,
#     'mainProduct': None,
#     'profileCategoryList': [{'category': 'subject',
#       'categoryName': '주제',
#       'categoryNo': 1,
#       'keywordList': [{'frequency': None,
#         'keyword': '에세이',
#         'keywordNo': 2265,
#         'no': 32,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '해외생활',
#         'keywordNo': 3533,
#         'no': 60,
#         'sequence': 1}]},
#      {'category': 'job',
#       'categoryName': '직업',
#       'categoryNo': 2,
#       'keywordList': [{'frequency': None,
#         'keyword': '회사원',
#         'keywordNo': 18150,
#         'no': 115,
#         'sequence': 0}]}],
#     'profileId': 'lypsone',
#     'profileImage': None,
#     'profileNotiExpireTime': 1632113288000,
#     'restrict0': False,
#     'restrictTime': None,
#     'socialUser': False,
#     'status': 'verify',
#     'talkChannelConnected': False,
#     'talkChannelProfile': None,
#     'userId': 'cFSs',
#     'userImage': 'http://k.kakaocdn.net/dn/bvCpva/btqFOSJvGVu/sBJ4A41uYC4ZyjCcd2br2k/img_640x640.jpg',
#     'userName': '칼립소',
#     'userSns': {'createTime': 1624962564000,
#      'facebook': None,
#      'instagram': None,
#      'twitter': None,
#      'updateTime': 1624962564000,
#      'userId': 'cFSs',
#      'website': ''},
#     'writerCount': 4},
#    'timestamp': 1631455514000},
#   {'article': {'arrivedLikeitCount': 10,
#     'articleCoverColorForHome': None,
#     'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/7swhfbT1Xg3cKik7MUkbPalvE_8.JPG',
#     'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/7swhfbT1Xg3cKik7MUkbPalvE_8.JPG',
#     'articleImageList': [{'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/7swhfbT1Xg3cKik7MUkbPalvE_8.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 544,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 2,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/aB3nrQxGiRyEdy2hjWiCMs_dqfI.png',
#       'userId': 'c0MI',
#       'width': 640},
#      {'articleNo': 77,
#       'height': 439,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 3,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/8CuhHVeKjWoj0P_zC3kfY6jn52o.png',
#       'userId': 'c0MI',
#       'width': 564},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 4,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/eUa7pQ3Tt6QSV15U92mAflpfgd0.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 5,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/4VD2o0dtuw6HZFQjWRp9fbUGngI.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 6,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/FphJZpmLBiueqNMSRRbI4xjaQww.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 7,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/RlGAC9D7EB-uA3BTuBjHIZEgj8o.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1817,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 8,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/IKJRmemYPnfEm01tnbVgWZLSwrg.JPG',
#       'userId': 'c0MI',
#       'width': 2605},
#      {'articleNo': 77,
#       'height': 1761,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 9,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/1bYmze5SWzRHpivFGNPNVxMMs6M.JPG',
#       'userId': 'c0MI',
#       'width': 2369},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 10,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/KjgrjqG4Qoc2qCBOL662fSLK3Sk.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 11,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/jIRZuuLvcGehdsZ4O6kSEABjCtY.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1756,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 12,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/diDKSowTZ75jPZRwbc7KwscKBRA.JPG',
#       'userId': 'c0MI',
#       'width': 2634},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 13,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/rPKsN2j-_8zX60SKQWiru25esTI.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1761,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 14,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/E1CW7jXSiUWK2pugbGqZEjJxS10.JPG',
#       'userId': 'c0MI',
#       'width': 2642},
#      {'articleNo': 77,
#       'height': 1657,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 15,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/GyBxKp_X7gsGjLzE9R2ASpmJRAE.JPG',
#       'userId': 'c0MI',
#       'width': 2243},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 16,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/Uyz_5IKxE9OCbvjg37guYpo-YCw.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1556,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 17,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/iBdGQyBqfJXD2IYFqZDxMd9Ult4.JPG',
#       'userId': 'c0MI',
#       'width': 2045},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 18,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/gcxEoFl1RndF87NPdIivvYFocqs.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 19,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/Eu0VEScqIGAejorN2NL_y54TkyE.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 20,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/3atlAyQZM323kp2zC5zyAXHez6k.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 21,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/JgFDt345zU15mAYzsmXEy2E-KMw.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 22,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/IMw8hAq_07B36oYDwoRAcTaWFvg.JPG',
#       'userId': 'c0MI',
#       'width': 2736},
#      {'articleNo': 77,
#       'height': 1536,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 23,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/7onmJ114mIkiU6WGCVAB-z1N-YE.JPG',
#       'userId': 'c0MI',
#       'width': 2048},
#      {'articleNo': 77,
#       'height': 1634,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 24,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/AQnWXOHxT70d136OYriKSNECYd4.JPG',
#       'userId': 'c0MI',
#       'width': 2290},
#      {'articleNo': 77,
#       'height': 443,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 25,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/tB78FjmDaatv-2ZJ25q8JBLomOI.jpg',
#       'userId': 'c0MI',
#       'width': 499},
#      {'articleNo': 77,
#       'height': 331,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 26,
#       'type': 'gridGallery',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/ccOWkff2rCbyKmff36kmLvptM5I.jpg',
#       'userId': 'c0MI',
#       'width': 369}],
#     'articleImageListForHome': [{'articleNo': 77,
#       'height': 1824,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/7swhfbT1Xg3cKik7MUkbPalvE_8.JPG',
#       'userId': 'c0MI',
#       'width': 2736}],
#     'articleKeywordNameAsCsv': None,
#     'articleKeywordNoAsCsv': None,
#     'articleKeywords': None,
#     'authorComment': '작가의 한마디가 나옵니다.',
#     'chapterNo': 0,
#     'commentCount': 2,
#     'commentWritable': True,
#     'content': None,
#     'contentHash': '111dc5f42601cfbc8a47d90e563fb6d96aff5fdb',
#     'contentId': 'c0MI_77',
#     'contentIdParam': None,
#     'contentSummary': '내가 무슨 다락논 탐사가라도 되는가 싶다. 3년 전 필리핀에서도 바나우에의 다락논을 보러 마닐라에서 10시간 넘게 버스 타고 다녀오지 않나, 쿤밍에서도 하루 종일 버스를 달려야 하는 웬양(元阳[Yuányáng] 원양)까지 혼자서라도 가겠다고 나서다니. 그러나 웬양의 다락논 사진을 한 번이라도 본 사람이라면 누구라도 마법에 끌린 듯 웬양을 향할 것이다. 일단',
#     'coverColor': None,
#     'coverInfo': None,
#     'createTime': 1631412701000,
#     'facebookShareCount': 0,
#     'flattenedSeq': 0,
#     'fromTime': None,
#     'homeDataSourceType': None,
#     'id': None,
#     'kakaoShareCount': 0,
#     'kakaoTalkShareCount': 0,
#     'likeCount': 14,
#     'magazineAddress': 'chinawetrip',
#     'magazineAddressUri': '/magazine/chinawetrip',
#     'magazineArticle': True,
#     'magazineArticleId': 0,
#     'magazineCoverImage': None,
#     'magazineNo': 108258,
#     'magazineStatus': 'publish',
#     'magazineTitle': '중국이 그렇게 좋아',
#     'magazineType': None,
#     'no': 77,
#     'nonMagazineArticle': False,
#     'notEmptyTitle': True,
#     'notPublished': False,
#     'orderBy': None,
#     'pick': False,
#     'profileId': 'fa8c37a4da78485',
#     'publishTime': 1631455078000,
#     'publishTimestamp': 1631455078690,
#     'published': True,
#     'readSeconds': 260,
#     'readTime': 0,
#     'restrictTime': None,
#     'seq': 0,
#     'socialShareTotalCount': 0,
#     'status': 'publish',
#     'subTitle': '',
#     'tempBrunchbookAddress': None,
#     'tempBrunchbookNo': 0,
#     'tempBrunchbookStatus': None,
#     'tempBrunchbookTitle': None,
#     'title': '자연과 인간의 합작품, 웬양의 다락논',
#     'toTime': None,
#     'twitterShareCount': 0,
#     'updateTime': 1631539955000,
#     'userId': 'c0MI',
#     'userName': None,
#     'version': None,
#     'viewCount': 0},
#    'profile': {'acceptPropose': True,
#     'articleCount': 67,
#     'articleViewType': 'TEXT',
#     'author': True,
#     'bookStoreBookList': [],
#     'brunchActivityList': [],
#     'company': '여행가',
#     'createTime': 1613997856000,
#     'description': '감성도 낭만도 없는 드라이한 여행기만 써대는 이과언니 & 생활여행자. 전생엔 새장에 갇힌 새, 이생엔 새장을 막 탈출한 여행자. 장래희망은 여행큐레이터.',
#     'descriptionDetail': '',
#     'emailValidation': True,
#     'followerCount': 70,
#     'magazineCount': 4,
#     'mainProduct': None,
#     'profileCategoryList': [{'category': 'subject',
#       'categoryName': '주제',
#       'categoryNo': 1,
#       'keywordList': [{'frequency': None,
#         'keyword': '여행',
#         'keywordNo': 2299,
#         'no': 33,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '독립출판',
#         'keywordNo': 18128,
#         'no': 11,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '라이프스타일',
#         'keywordNo': 1167,
#         'no': 14,
#         'sequence': 2}]}],
#     'profileId': 'fa8c37a4da78485',
#     'profileImage': None,
#     'profileNotiExpireTime': 1629596301000,
#     'restrict0': False,
#     'restrictTime': None,
#     'socialUser': False,
#     'status': 'verify',
#     'talkChannelConnected': False,
#     'talkChannelProfile': None,
#     'userId': 'c0MI',
#     'userImage': 'http://t1.daumcdn.net/brunch/service/user/c0MI/image/6QhwHUMwoWXElkFim1IRL69Ry3I.jpg',
#     'userName': '위트립',
#     'userSns': {'createTime': 1625187843000,
#      'facebook': None,
#      'instagram': None,
#      'twitter': None,
#      'updateTime': 1625187843000,
#      'userId': 'c0MI',
#      'website': 'http://blog.naver.com/wetrip'},
#     'writerCount': 65},
#    'timestamp': 1631455078000},
#   {'article': {'arrivedLikeitCount': 10,
#     'articleCoverColorForHome': None,
#     'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/T6kv32Rg1TEO2uSNoRwXV2fm1TQ.jpg',
#     'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/T6kv32Rg1TEO2uSNoRwXV2fm1TQ.jpg',
#     'articleImageList': [{'articleNo': 10,
#       'height': 2988,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/T6kv32Rg1TEO2uSNoRwXV2fm1TQ.jpg',
#       'userId': '8rC7',
#       'width': 5312},
#      {'articleNo': 10,
#       'height': 5312,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 2,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/BS4Ey8luETSi2nxsOpIwnFmCXcE',
#       'userId': '8rC7',
#       'width': 2988},
#      {'articleNo': 10,
#       'height': 5312,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 3,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/mT8y3PYlSYe07eckSBslkXA8ekQ',
#       'userId': '8rC7',
#       'width': 2988},
#      {'articleNo': 10,
#       'height': 5312,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 4,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/fs5AGIo80pVTmMJE3JAgBaRP2Kc',
#       'userId': '8rC7',
#       'width': 2988},
#      {'articleNo': 10,
#       'height': 2988,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 5,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/_jQlJ9FKzWtNIMMaNJUtdIzLsRQ.jpg',
#       'userId': '8rC7',
#       'width': 4437},
#      {'articleNo': 10,
#       'height': 3505,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 6,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/DMm2-83Jk4tcU0YUrnPmUjLfmuA.jpg',
#       'userId': '8rC7',
#       'width': 2988},
#      {'articleNo': 10,
#       'height': 1073,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 7,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/4vdCkKpC-85QkdYsbyBIAROC860',
#       'userId': '8rC7',
#       'width': 1080},
#      {'articleNo': 10,
#       'height': 1449,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 8,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/ZlH_qiyCzFy_Y7E2k4b-PN7z2f0.jpg',
#       'userId': '8rC7',
#       'width': 1200},
#      {'articleNo': 10,
#       'height': 960,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 9,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/q4eQOy2P6AMH5veAFOKMtbfawFA',
#       'userId': '8rC7',
#       'width': 1440},
#      {'articleNo': 10,
#       'height': 2448,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 10,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/0L6ixI2w-T-QhlmqgWjbp5BLfdg',
#       'userId': '8rC7',
#       'width': 3264},
#      {'articleNo': 10,
#       'height': 1280,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 11,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/vkzYEIhaSovMcHLAxw-BiAFmp1M',
#       'userId': '8rC7',
#       'width': 1184},
#      {'articleNo': 10,
#       'height': 3264,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 12,
#       'type': 'image',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/la0ePDzNUV_p_C0TPdK_ggDLttA',
#       'userId': '8rC7',
#       'width': 2448}],
#     'articleImageListForHome': [{'articleNo': 10,
#       'height': 2988,
#       'magazineNo': None,
#       'magazineNoList': None,
#       'order': 1,
#       'type': 'cover',
#       'url': 'http://t1.daumcdn.net/brunch/service/user/8rC7/image/T6kv32Rg1TEO2uSNoRwXV2fm1TQ.jpg',
#       'userId': '8rC7',
#       'width': 5312}],
#     'articleKeywordNameAsCsv': None,
#     'articleKeywordNoAsCsv': None,
#     'articleKeywords': None,
#     'authorComment': '작가의 한마디가 나옵니다.',
#     'chapterNo': 0,
#     'commentCount': 0,
#     'commentWritable': True,
#     'content': None,
#     'contentHash': '1953a55582f196ac70b882c304f6ea40f8d85afe',
#     'contentId': '8rC7_10',
#     'contentIdParam': None,
#     'contentSummary': "휴학 후 8개월 간 온갖 아르바이트를 섭렵했다.  한 트럭 완판 기록을 세우며 사장님께 두둑한 보너스를 받았던 석가탄신일 조계사 앞 짝퉁 가방 판매 알바, 무작위 번호를 추출하여 스팸성 전화를 돌리는 것을 '아웃바운딩'이란 고급진 단어로 칭하던 과외 알선 아웃바운딩 알바, 점잖게 와인으로 시작해서 소주로 만취되어 나가시는 손님들이 가득했던 자취방 바로 앞 ",
#     'coverColor': None,
#     'coverInfo': None,
#     'createTime': 1631403997000,
#     'facebookShareCount': 0,
#     'flattenedSeq': 0,
#     'fromTime': None,
#     'homeDataSourceType': None,
#     'id': None,
#     'kakaoShareCount': 0,
#     'kakaoTalkShareCount': 0,
#     'likeCount': 14,
#     'magazineAddress': 'cos1x',
#     'magazineAddressUri': '/magazine/cos1x',
#     'magazineArticle': True,
#     'magazineArticleId': 0,
#     'magazineCoverImage': None,
#     'magazineNo': 115079,
#     'magazineStatus': 'publish',
#     'magazineTitle': '9월의 러시아와 시베리아 횡단열차',
#     'magazineType': None,
#     'no': 10,
#     'nonMagazineArticle': False,
#     'notEmptyTitle': True,
#     'notPublished': False,
#     'orderBy': None,
#     'pick': False,
#     'profileId': 'dud2wlfjd',
#     'publishTime': 1631450107000,
#     'publishTimestamp': 1631450107688,
#     'published': True,
#     'readSeconds': 284,
#     'readTime': 0,
#     'restrictTime': None,
#     'seq': 0,
#     'socialShareTotalCount': 0,
#     'status': 'publish',
#     'subTitle': '짠내 나지만은 않은, 사람 사랑 일기 그 첫 장',
#     'tempBrunchbookAddress': None,
#     'tempBrunchbookNo': 0,
#     'tempBrunchbookStatus': None,
#     'tempBrunchbookTitle': None,
#     'title': '러시아부터 시작된 110일 배낭여행, 그 프롤로그',
#     'toTime': None,
#     'twitterShareCount': 0,
#     'updateTime': 1631548751000,
#     'userId': '8rC7',
#     'userName': None,
#     'version': None,
#     'viewCount': 0},
#    'profile': {'acceptPropose': True,
#     'articleCount': 3,
#     'articleViewType': 'TEXT',
#     'author': True,
#     'bookStoreBookList': [],
#     'brunchActivityList': [],
#     'company': '',
#     'createTime': 1569595796000,
#     'description': '어느 때에 벌어진 사건과 생각, 그리고 함께한 사람들과의 이야기를 기록합니다.',
#     'descriptionDetail': '',
#     'emailValidation': True,
#     'followerCount': 9,
#     'magazineCount': 2,
#     'mainProduct': None,
#     'profileCategoryList': [{'category': 'subject',
#       'categoryName': '주제',
#       'categoryNo': 1,
#       'keywordList': [{'frequency': None,
#         'keyword': '해외생활',
#         'keywordNo': 3533,
#         'no': 60,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '여행',
#         'keywordNo': 2299,
#         'no': 33,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '에세이',
#         'keywordNo': 2265,
#         'no': 32,
#         'sequence': 2}]},
#      {'category': 'job',
#       'categoryName': '직업',
#       'categoryNo': 2,
#       'keywordList': [{'frequency': None,
#         'keyword': '기획자',
#         'keywordNo': 850,
#         'no': 75,
#         'sequence': 0},
#        {'frequency': None,
#         'keyword': '에세이스트',
#         'keywordNo': 128924,
#         'no': 96,
#         'sequence': 1},
#        {'frequency': None,
#         'keyword': '연구자',
#         'keywordNo': 97402,
#         'no': 125,
#         'sequence': 2}]}],
#     'profileId': 'dud2wlfjd',
#     'profileImage': None,
#     'profileNotiExpireTime': 1630395386000,
#     'restrict0': False,
#     'restrictTime': None,
#     'socialUser': False,
#     'status': 'verify',
#     'talkChannelConnected': False,
#     'talkChannelProfile': None,
#     'userId': '8rC7',
#     'userImage': 'http://t1.daumcdn.net/brunch/service/guest/image/YjaKXkeWAJufXSmVuEE17C0hNpU.jpg',
#     'userName': '민영',
#     'userSns': {'createTime': 1629786195000,
#      'facebook': None,
#      'instagram': 'min0_delta_sim/',
#      'twitter': None,
#      'updateTime': 1629786195000,
#      'userId': '8rC7',
# ...
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 3858,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 4100,
#    'keyword': '영국여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 4100,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 18424,
#    'keyword': '방콕여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 18424,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 5456,
#    'keyword': '동남아여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 5456,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 4056,
#    'keyword': '아프리카여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 4056,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 4285,
#    'keyword': '터키여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 4285,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 18475,
#    'keyword': '유럽여행기',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 18475,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 3936,
#    'keyword': '북유럽여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 3936,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 18472,
#    'keyword': '캐나다여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 18472,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 3804,
#    'keyword': '네팔여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 3804,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 18466,
#    'keyword': '공정여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 18466,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0},
#   {'agentId': None,
#    'articleCount': 0,
#    'bannerOnoff': None,
#    'count': 1,
#    'createTime': None,
#    'displaySource': None,
#    'finalScore': 0.0,
#    'frequency': None,
#    'id': 4251,
#    'keyword': '캄보디아여행',
#    'link': None,
#    'mobileBackgroundColor': None,
#    'mobileImageLink': None,
#    'mobileImageUrl': None,
#    'mobileTextImage': None,
#    'multipleNo': None,
#    'no': 4251,
#    'onoff': None,
#    'orderType': None,
#    'pcBackgroundColor': None,
#    'pcImageLink': None,
#    'pcImageUrl': None,
#    'pcTextImage': None,
#    'percent': 0,
#    'promotion': False,
#    'rank': 0,
#    'score': 0,
#    'selected': None,
#    'source': None,
#    'type': 'white',
#    'updateTime': None,
#    'userCount': 0}],
#  'moreList': True,
#  'profileList': [{'acceptPropose': True,
#    'articleCount': 64,
#    'articleViewCount': 0,
#    'articleViewType': 'IMAGE',
#    'author': True,
#    'bookStoreBookList': [],
#    'brunchActivityList': [],
#    'company': '라이징유',
#    'createTime': 1466088246000,
#    'description': '육지에 사는 제주 여행 중독자.',
#    'descriptionDetail': '- 공군 학사장교 126기\n- 네이버 포스트 여행 에디터 데뷔 프로젝트 시즌2\n- 제주도 다이어트 트레킹 저자(JNC커뮤니티)\n- 브루웍스 아카데미 Beer Intensive Course 4기\n- 관광통역안내사(영어), 제주 택시운전자격증 보유\n- 네이버오디오클립 오! 스타 프로젝트 시즌 1',
#    'descriptionHighlight': None,
#    'emailValidation': True,
#    'followerCount': 283,
#    'keywords': None,
#    'keywordsHighlight': None,
#    'magazineCount': 0,
#    'mainProduct': None,
#    'myFollower': False,
#    'myWriter': False,
#    'profileCategoryList': None,
#    'profileId': 'jejur2',
#    'profileImage': None,
#    'profileNotiExpireTime': 1616777402000,
#    'restrict0': False,
#    'restrictTime': None,
#    'socialUser': False,
#    'status': 'verify',
#    'talkChannelConnected': False,
#    'talkChannelProfile': None,
#    'userId': '24v4',
#    'userImage': 'http://t1.daumcdn.net/brunch/service/user/24v4/image/dUB41dVYNbh2nGTJw1wAT_bFOxg.jpg',
#    'userName': '제주앓이',
#    'userNameHighlight': None,
#    'userSns': {'createTime': 1533638907000,
#     'facebook': None,
#     'instagram': 'jejur2',
#     'twitter': None,
#     'updateTime': 1616172602000,
#     'userId': '24v4',
#     'website': 'https://post.naver.com/risingyou21'},
#    'writerCount': 15},
#   {'acceptPropose': True,
#    'articleCount': 204,
#    'articleViewCount': 0,
#    'articleViewType': 'IMAGE',
#    'author': True,
#    'bookStoreBookList': [],
#    'brunchActivityList': [],
#    'company': '',
#    'createTime': 1465970229000,
#    'description': '때론 허세롭지만 진실된 하루하루를 기대합니다.',
#    'descriptionDetail': '',
#    'descriptionHighlight': None,
#    'emailValidation': True,
#    'followerCount': 1442,
#    'keywords': None,
#    'keywordsHighlight': None,
#    'magazineCount': 0,
#    'mainProduct': None,
#    'myFollower': False,
#    'myWriter': False,
#    'profileCategoryList': None,
#    'profileId': 'dayemotion',
#    'profileImage': None,
#    'profileNotiExpireTime': 1563887638000,
#    'restrict0': False,
#    'restrictTime': None,
#    'socialUser': False,
#    'status': 'verify',
#    'talkChannelConnected': False,
#    'talkChannelProfile': None,
#    'userId': '24ea',
#    'userImage': 'http://t1.daumcdn.net/brunch/service/user/24ea/image/R6VvTTfQFzHegTSAH-vhZuCnrgg.JPG',
#    'userName': '본격감성허세남',
#    'userNameHighlight': None,
#    'userSns': {'createTime': 1533354960000,
#     'facebook': '',
#     'instagram': '',
#     'twitter': '',
#     'updateTime': 1533354960000,
#     'userId': '24ea',
#     'website': ''},
#    'writerCount': 6},
#   {'acceptPropose': True,
#    'articleCount': 12,
#    'articleViewCount': 0,
#    'articleViewType': 'TEXT',
#    'author': True,
#    'bookStoreBookList': [],
#    'brunchActivityList': [],
#    'company': '페이퍼백아카이브',
#    'createTime': 1456655536000,
#    'description': '흘러가지만 기억하고픈, 삶의 순간을 기록하고 있습니다',
#    'descriptionDetail': '2018 여자를 위한 여행잡지 <여행여락> 창간 \n2019 <여자들의 도시 아카이브북: 서울의 기억> 발간 \n2020 <젠더+시티 트래블> 발간, <선미촌 아카이브북 2000 - 2020>  발간 \n2021 아산여성아카이브 프롤로그전 총괄큐레이터',
#    'descriptionHighlight': None,
#    'emailValidation': True,
#    'followerCount': 54,
#    'keywords': None,
#    'keywordsHighlight': None,
#    'magazineCount': 0,
#    'mainProduct': None,
#    'myFollower': False,
#    'myWriter': False,
#    'profileCategoryList': None,
#    'profileId': 'feministraveler',
#    'profileImage': None,
#    'profileNotiExpireTime': 1626160485000,
#    'restrict0': False,
#    'restrictTime': None,
#    'socialUser': False,
#    'status': 'verify',
#    'talkChannelConnected': False,
#    'talkChannelProfile': None,
#    'userId': '1gIB',
#    'userImage': 'http://t1.daumcdn.net/brunch/service/user/1gIB/image/05jODEu53xvK2MGuRy7X9SkE9RQ.jpg',
#    'userName': '페이퍼백',
#    'userNameHighlight': None,
#    'userSns': {'createTime': 1624861180000,
#     'facebook': 'nayoon.heo/',
#     'instagram': 'feministraveler',
#     'twitter': None,
#     'updateTime': 1624861180000,
#     'userId': '1gIB',
#     'website': 'https://www.archivew.info/'},
#    'writerCount': 9},
#   {'acceptPropose': True,
#    'articleCount': 70,
#    'articleViewCount': 0,
#    'articleViewType': 'TEXT',
#    'author': True,
#    'bookStoreBookList': [],
#    'brunchActivityList': [],
#    'company': '',
#    'createTime': 1455062914000,
#    'description': '샌디에고 살고있는 Writer, Golfer 그리고 Technologist...',
#    'descriptionDetail': '',
#    'descriptionHighlight': None,
#    'emailValidation': True,
#    'followerCount': 87,
#    'keywords': None,
#    'keywordsHighlight': None,
#    'magazineCount': 0,
#    'mainProduct': None,
#    'myFollower': False,
#    'myWriter': False,
#    'profileCategoryList': None,
#    'profileId': 'tystory',
#    'profileImage': None,
#    'profileNotiExpireTime': 1620480677000,
#    'restrict0': False,
#    'restrictTime': None,
#    'socialUser': False,
#    'status': 'verify',
#    'talkChannelConnected': False,
#    'talkChannelProfile': None,
#    'userId': '1bAk',
#    'userImage': 'http://t1.daumcdn.net/brunch/service/guest/image/Nf2CMLkY3x_EUD8HObGo4rPszeM',
#    'userName': '타이킴',
#    'userNameHighlight': None,
#    'userSns': {'createTime': 1579821313000,
#     'facebook': None,
#     'instagram': None,
#     'twitter': None,
#     'updateTime': 1619875877000,
#     'userId': '1bAk',
#     'website': ''},
#    'writerCount': 3},
#   {'acceptPropose': True,
#    'articleCount': 56,
#    'articleViewCount': 0,
#    'articleViewType': 'TEXT',
#    'author': True,
#    'bookStoreBookList': [],
#    'brunchActivityList': [],
#    'company': '',
#    'createTime': 1465224050000,
#    'description': '일상이 외국인과 함께인 나. 한국문화와 한국어를 가르치는 일을 하는 나. 그리스인 셰프가 남편. 그 일상을 기록한다. 아, 요즘은 기억을 더듬어 어린 시절을 기록하...다가...',
#    'descriptionDetail': '',
#    'descriptionHighlight': None,
#    'emailValidation': True,
#    'followerCount': 201,
#    'keywords': None,
#    'keywordsHighlight': None,
#    'magazineCount': 0,
#    'mainProduct': None,
#    'myFollower': False,
#    'myWriter': False,
#    'profileCategoryList': None,
#    'profileId': 'sol21c',
#    'profileImage': None,
#    'profileNotiExpireTime': 1622707617000,
#    'restrict0': False,
#    'restrictTime': None,
#    'socialUser': False,
#    'status': 'verify',
#    'talkChannelConnected': False,
#    'talkChannelProfile': None,
#    'userId': '22wh',
#    'userImage': 'http://t1.daumcdn.net/brunch/service/user/22wh/image/789-QTSIVN8Ij6e_RETzh5mLU5E.jpg',
#    'userName': '그릭아낙',
#    'userNameHighlight': None,
#    'userSns': {'createTime': 1569075233000,
#     'facebook': None,
#     'instagram': None,
#     'twitter': None,
#     'updateTime': 1622102797000,
#     'userId': '22wh',
#     'website': ''},
#    'writerCount': 101},
#   {'acceptPropose': True,
#    'articleCount': 6,
#    'articleViewCount': 0,
#    'articleViewType': 'TEXT',
#    'author': True,
#    'bookStoreBookList': [],
#    'brunchActivityList': [],
#    'company': '',
#    'createTime': 1464358186000,
#    'description': '한량의 삶을 그리는 도비. 좋아하는 것, 되고 싶은 것이 참 많았던 아이는 이것저것 하다보니 이도저도 아닌 애매한 사람이 되었다. 현재는 햇-마:당의 편집장으로 활동하고 있다.',
#    'descriptionDetail': '',
#    'descriptionHighlight': None,
#    'emailValidation': True,
#    'followerCount': 16,
#    'keywords': None,
#    'keywordsHighlight': None,
#    'magazineCount': 0,
#    'mainProduct': None,
#    'myFollower': False,
#    'myWriter': False,
#    'profileCategoryList': None,
#    'profileId': 'chaereen',
#    'profileImage': None,
#    'profileNotiExpireTime': 1623059406000,
#    'restrict0': False,
#    'restrictTime': None,
#    'socialUser': False,
#    'status': 'verify',
#    'talkChannelConnected': False,
#    'talkChannelProfile': None,
#    'userId': '20s5',
#    'userImage': 'http://t1.daumcdn.net/brunch/service/user/20s5/image/EWQy_39dXS2xOKvOw4jn3VbZjTo.jpg',
#    'userName': '채린',
#    'userNameHighlight': None,
#    'userSns': {'createTime': 1562784578000,
#     'facebook': None,
#     'instagram': 'chaereen',
#     'twitter': None,
#     'updateTime': 1622453878000,
#     'userId': '20s5',
#     'website': 'https://www.hetmadang.com'},
#    'writerCount': 6}]}

# %%
test2 = test['articleList']
test3 = test2.get('contentSummary')
test3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-7b139e7af366> in <module>()
#       1 test2 = test['articleList']
# ----> 2 test3 = test2.get('contentSummary')
#       3 test3
#
# AttributeError: 'list' object has no attribute 'get'

# %%
for d in test['articleList']:
    print(d['contentSummary'])

    publishTime = data['publishTime'] #0


    time.sleep(1)

    

#print(data['moreList'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-2e933afaff8e> in <module>()
#       1 for d in test['articleList']:
# ----> 2     print(d['contentSummary'])
#       3
#       4     publishTime = data['publishTime'] #0
#       5
#
# KeyError: 'contentSummary'

# %%
    for d in data['data']:
        print(d['keyword'])

    publishTime = data['publishTime'] #0


    time.sleep(1)

    

#print(data['moreList'])

# %%
import requests
import json
import time

magazineOffset = 0
contestOffset = 0
exhibitOffset = 0
galleryOffset = 0

for i in range(10): # 0~9

    params = {
        'magazineOffset': magazineOffset
        ,'contestOffset': contestOffset
        ,'exhibitOffset': exhibitOffset
        ,'galleryOffset': galleryOffset
    }

    response = requests.get("https://www.jungle.co.kr/recent.json", params=params)
    data = json.loads(response.text)
# Out:
# {'exhibitOffset': 0, 'existMore': True, 'contestOffset': 4, 'success': True, 'galleryOffset': 0, 'moreList': [{'id': 203300, 'title': '문화다양성 축제 MAMF 2021 자원봉사단 모집', 'thumbnailImageId': 'cb866d044daca03513d0c708', 'secondaryThumbnailImageId': 'a24b04b4407093771e3ec127', 'confirmedDate': '21-09-13', 'originalCreatedDate': 1631527790000, 'targetCode': '공모전', 'targetName': 'contest'}, {'id': 203299, 'title': '람사르습지도시 홍보 영상 콘텐츠 공모전', 'thumbnailImageId': 'cfa888ba4df585cac9b0af91', 'secondaryThumbnailImageId': '9a725dae425ca1e9d97da218', 'confirmedDate': '21-09-13', 'originalCreatedDate': 1631520492000, 'targetCode': '공모전', 'targetName': 'contest'}, {'id': 203298, 'title': '2021 핀업컨셉디자인어워드', 'thumbnailImageId': '1058f8714c0d86e3c853f929', 'secondaryThumbnailImageId': '8598c6534f4f8ba4d1d03fb0', 'confirmedDate': '21-09-13', 'originalCreatedDate': 1631500228000, 'targetCode': '공모전', 'targetName': 'contest'}, {'id': 203388, 'title': '[디자인 화제] 2021 세계그래픽아트페어, 오는 10월 10일, 3개 도시에서 동시 열린다', 'thumbnailImageId': '8cbf3dba462baec81cf98d18', 'confirmedDate': '21-09-13', 'originalCreatedDate': 1631491629000, 'targetCode': '매거진', 'targetName': 'magazine'}, {'id': 203297, 'title': '대학생 서포터즈 제6기 커피라이터 맥심취향저격대 모집', 'thumbnailImageId': 'befa87174144941c55930c55', 'secondaryThumbnailImageId': '1051a36640c88d77bd6cef15', 'confirmedDate': '21-09-13', 'originalCreatedDate': 1631491575000, 'targetCode': '공모전', 'targetName': 'contest'}, {'id': 203387, 'title': "광화문국제단편영화제, '다시 세움'의 가치 담은 공식 포스터 공개", 'thumbnailImageId': 'b4e2031b4d5baf8c940af95c', 'confirmedDate': '21-09-13', 'originalCreatedDate': 1631491551000, 'targetCode': '매거진', 'targetName': 'magazine'}], 'magazineOffset': 2}

# %%
    for d in data['moreList']:
        print(d['title'])
        print(d['targetCode'])

    magazineOffset = data['magazineOffset'] #0
    contestOffset = data['contestOffset'] #6
    exhibitOffset = data['exhibitOffset'] #0
    galleryOffset = data['galleryOffset'] #0

    time.sleep(1)

    

#print(data['moreList'])
# Out:
#   File "<ipython-input-26-abe2d54b6b76>", line 2
#     for d in data['moreList']:
#     ^
# IndentationError: unexpected indent
