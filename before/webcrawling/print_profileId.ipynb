# %% [markdown]
# <a href="https://colab.research.google.com/github/2pterons/twigfarm/blob/main/webcrawling/print_profileId.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import time
import random
from bs4 import BeautifulSoup

# %%
int_time = 1632646210000
str_time = "1632646210000"

for a in range(0, 4):
  int_time += 1
  str_time = str(int_time)
  print(str_time)
# Out:
# 1632646210001
# 1632646210002
# 1632646210003
# 1632646210004

# %%
url = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime=1632646210000&pickContentId="
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
int_time = 1632646210000
str_time = "1632646210000"
profile_list = []

variables = {
              "publishTime":"1632646210000"
              ,"pickContentId":None
    }

params = {
            "variables":json.dumps(variables)
    }

rs = requests.get(url, params=params, headers=headers)
js = json.loads(rs.text)
js
# Out:
# {'code': 200,
#  'data': {'articleList': [{'article': {'arrivedLikeitCount': 0,
#      'articleCoverColorForHome': None,
#      'articleImageForDiscover': 'http://t1.daumcdn.net/brunch/service/user/cUjk/image/GQ6HoJqsNoQv11yqJc2jCWTVjNo.jpeg',
#      'articleImageForHome': 'http://t1.daumcdn.net/brunch/service/user/cUjk/image/CCHrssepC0NWJgXmah-p4pPcvRU',
#      'articleImageList': [{'articleNo': 4,
#        'height': 536,
#        'magazineNo': None,
#        'magazineNoList': None,
#        'order': 1,
#        'type': 'image',
#        'url': 'http://t1.daumcdn.net/brunch/service/user/cUjk/image/CCHrssepC0NWJgXmah-p4pPcvRU',
#        'userId': 'cUjk',
#        'width': 750},
#       {'articleNo': 4,
#        'height': 1024,
#        'magazineNo': None,
#        'magazineNoList': None,
#        'order': 2,
#        'type': 'image',
#        'url': 'http://t1.daumcdn.net/brunch/service/user/cUjk/image/GQ6HoJqsNoQv11yqJc2jCWTVjNo.jpeg',
#        'userId': 'cUjk',
# ...

# %%
# 0부터 19까지(20개 게시물) 로드되고 재로드 후 다시 0부터 19
def getProfileId():
  url = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime=1632646210000&pickContentId={}"
  headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
  int_time = 1632646210000
  str_time = "1632646210000"
  profile_list = []

  for i in range(0, 2):
    variables = {
              "publishTime":str_time
              ,"pickContentId":""
    }

    params = {
            "variables":json.dumps(variables)
    }

    rs = requests.get(url, params=params, headers=headers)
    js = json.loads(rs.text)
    for x in range(0, 20):
      profileId = js['data']['articleList'][x]['article']['profileId']
      profile_list.append(profileId)

      time.sleep(random.uniform(2,4))
    
    int_time += 1
    str_time = str(int_time)
    print(rs.text)
  return rs.text, profile_list

# %%
url = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime=1632646210000&pickContentId={}"
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
int_time = 1632646210000
str_time = "1632646210000"
profile_list = []

for i in range(0, 2):
  variables = {
            "publishTime":str_time
            ,"pickContentId":""
  }

  params = {
          "variables":json.dumps(variables)
  }

  rs = requests.get(url, params=params, headers=headers)
  js = json.loads(rs.text)
  for x in range(0, 2):
    profileId = js['data']['articleList'][x]['article']['profileId']
    profile_list.append(profileId)

    time.sleep(random.uniform(2,4))
  
  int_time += 1
  str_time = str(int_time)
  print(rs.text)
# Out:
# {"desc":"OK","code":200,"title":"","extra":"","data":{"keyword":"지구한바퀴 세계여행","profileList":[{"userId":"1ZsQ","userName":"Hae","userImage":"http://t1.daumcdn.net/brunch/service/user/1ZsQ/image/KEV1iKRd5RpqovyRUxyFLcQNd5k.png","profileId":"haeinoslo","profileImage":null,"description":"오슬로에서  디자이너로 활동중입니다. 헨릭 입센 뮤지엄 전시 공간 디자인 및 새로운 뭉크뮤지엄 상설 전시 디자인 참여했습니다.","createTime":1463991760000,"status":"verify","articleCount":34,"socialUser":false,"writerCount":4,"followerCount":759,"magazineCount":0,"company":"","descriptionDetail":"오슬로 거주중인  디자이너 / 작가\n-\n연합뉴스 인터뷰 www.youtube.com/watch?v=x05-75EZORE&t=31s\n2017- 현재. Hae Yoon Design \n2019 - 2020. Expology, Oslo \n2013-2017  현대백화점 본사  VMD팀 - 그래픽 & 공간 디자이너\n2011 광주 디자인 비엔날레 프로젝트 코디네이터\n2011 호주 Monash 대학 BFA 졸업","profileNotiExpireTime":1631866833000,"userSns":{"userId":"1ZsQ","website":"http://hae-yoon.com","facebook":null,"twitter":null,"instagram":"hae.norway.design","createTime":1533494370000,"updateTime":1631262033000},"bookStoreBookList":[],"p
# ...

# %%
profile_id = getProfileId()

# %%
len(profile_id), profile_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1cb61e26e58b> in <module>()
# ----> 1 len(profile_id), profile_id
#
# NameError: name 'profile_id' is not defined

# %%
category = "https://brunch.co.kr/keyword/%EC%A7%80%EA%B5%AC%ED%95%9C%EB%B0%94%ED%80%B4_%EC%84%B8%EA%B3%84%EC%97%AC%ED%96%89?q=g"
menu = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime={}&pickContentId={}"
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}

imsi_num = 1632646211000
imsi_num2 = 1632642812000 
imsi_profileId = 'leobusan'

'''
variables = json.dumps({
            "publishTime":1632646211000
            ,"pickContentId":""
}, sort_keys=True, ensure_ascii=False)
'''
variables = {
            "publishTime":1632646210000
            ,"pickContentId":""
}

params = {
          "variables":json.dumps(variables)
}


#menu = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime={}&pickContentId=".format(variables)
menu = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime=1632646210000&pickContentId="
imsii = requests.get(menu, params=params, headers=headers)
#imsii = requests.get(menu, headers=headers)

# %%
print(imsii.status_code), print(imsii.text)
# Out:
# 200
# ...

# %%
print(imsii.status_code), print(imsii.text)
# Out:
# 200
# ...

# %%
print(imsii.status_code), print(imsii.text)
# Out:
# 200
# ...

# %%
imsii.text
# Out:
# '{"desc":"OK","code":200,"title":"","extra":"","data":{"keyword":"지구한바퀴 세계여행","profileList":[{"userId":"1gIB","userName":"페이퍼백","userImage":"http://t1.daumcdn.net/brunch/service/user/1gIB/image/05jODEu53xvK2MGuRy7X9SkE9RQ.jpg","profileId":"feministraveler","profileImage":null,"description":"흘러가지만 기억하고픈, 삶의 순간을 기록하고 있습니다","createTime":1456655536000,"status":"verify","articleCount":12,"socialUser":false,"writerCount":9,"followerCount":56,"magazineCount":0,"company":"페이퍼백아카이브","descriptionDetail":"2018 여자를 위한 여행잡지 <여행여락> 창간 \\n2019 <여자들의 도시 아카이브북: 서울의 기억> 발간 \\n2020 <젠더+시티 트래블> 발간, <선미촌 아카이브북 2000 - 2020>  발간 \\n2021 아산여성아카이브 프롤로그전 총괄큐레이터","profileNotiExpireTime":1626160485000,"userSns":{"userId":"1gIB","website":"https://www.archivew.info/","facebook":"nayoon.heo/","twitter":null,"instagram":"feministraveler","createTime":1624861180000,"updateTime":1624861180000},"bookStoreBookList":[],"profileCategoryList":null,"mainProduct":null,"acceptPropose":true,"articleViewType":"TEXT","brunchAc
# ...

# %%
len(ms['data']['articleList'][1])

# %%
imsi_bs = BeautifulSoup(imsii.content, 'html.parser')

# %%
imsi_bs = BeautifulSoup(imsii.text, 'html.parser')

# %%
type(imsi_bs), imsi_bs

# %%
imsi_bs.

# %%
def startCrawling():
  url = "https://brunch.co.kr/@{}/{}"
  for q in profile_id:
    variables = {"q":x
                ,"g":y}
  params = {"variables":variables}
  headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
  rs = requests.get(url, params=params, headers=headers)

# %%
url = "https://brunch.co.kr/@leobusan/1"

variables = {"q":
    
}
params = {"variables":variables}

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
re = requests.get(url, headers=headers)

# %%
bs = BeautifulSoup(re.content, 'html.parser')
print(bs)

# %%
bs.select('.wrap_body .wrap_item')[0]['data-app']

# %%
text = bs.select('.wrap_body .wrap_item')[0]['data-app']

# %%
bs.select('.wrap_body .wrap_item')[13]['data-app']

# %%
text = bs.select('.wrap_body .wrap_item')

# %%
type(text)

# %%
import re
num = len(text)
type(num), num

# %%
result = []
for i in range(0, 13):
  imsi = bs.select('.wrap_body .wrap_item')[i]['data-app']
  for j in range(1, i):
    cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'{}()\'…》]', '', imsi)
    cleaned_text.strip()
  result.append(cleaned_text)

# %%
result
