# %% [markdown]
# <a href="https://colab.research.google.com/github/2pterons/twigfarm/blob/main/webcrawling/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import time
import random
import requests
import json
import urllib
from bs4 import BeautifulSoup

# %%
profile_list = []
result = []

profile_url = 'https://api.brunch.co.kr/v1/top/keyword/group/38'
profile_headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}

int_time = 1632701583000
str_time = "1632701582000"
            #1632701582000

for i in range(0, 10):
  variables = {
      "publishTime":str_time
      ,"pickContentId":None
  }
  profile_params = {
      "variables":json.dumps(variables)
  }

  rs = requests.get(profile_url, params=profile_params, headers=profile_headers)
  js = json.loads(rs.text)
  delete = []
  for j in range(0, 19):
    profileId = js['data']['articleList'][j]['article']['profileId']
    delete.append(profileId)
    for overlap in delete:
      if overlap not in profile_list:
        profile_list.append(overlap)


  int_time += 1385761
  str_time = str(int_time)
  print(str_time)

  time.sleep(random.uniform(2,6))  
  print(profile_list)
# Out:
# 1632702968761
# ['chihe2002', 'carson52', 'doahfather', 'joogangl', 'jinhokim', 'sarah21an', 'borabarabam', 'b3806b90e737406', 'freshshin20', 'onvacation', 'jeongilkhom', 'santiagolee', 'hyoun609', 'nangrang77', 'dinggiriboram', 'stayfolio', 'alleyna2005', 'shalomu', 'dear-days']
# 1632704354522
# ['chihe2002', 'carson52', 'doahfather', 'joogangl', 'jinhokim', 'sarah21an', 'borabarabam', 'b3806b90e737406', 'freshshin20', 'onvacation', 'jeongilkhom', 'santiagolee', 'hyoun609', 'nangrang77', 'dinggiriboram', 'stayfolio', 'alleyna2005', 'shalomu', 'dear-days']
# 1632705740283
# ['chihe2002', 'carson52', 'doahfather', 'joogangl', 'jinhokim', 'sarah21an', 'borabarabam', 'b3806b90e737406', 'freshshin20', 'onvacation', 'jeongilkhom', 'santiagolee', 'hyoun609', 'nangrang77', 'dinggiriboram', 'stayfolio', 'alleyna2005', 'shalomu', 'dear-days']
# 1632707126044
# ...

# %%
js['data']['articleList'][19]['article']['profileId']
# Out:
# '6911f9aa6a64406'

# %%
profile_list
# Out:
# ['chihe2002',
#  'carson52',
#  'doahfather',
#  'joogangl',
#  'jinhokim',
#  'sarah21an',
#  'borabarabam',
#  'b3806b90e737406',
#  'freshshin20',
#  'onvacation',
#  'jeongilkhom',
#  'santiagolee',
#  'hyoun609',
#  'nangrang77',
#  'dinggiriboram',
#  'stayfolio',
#  'alleyna2005',
#  'shalomu',
#  'dear-days']

# %%
for q in profile_list:
  for g in range(2, 13):
    t_str = "https://brunch.co.kr/@{}/{}".format(q,g)
    print(t_str)
# Out:
# https://brunch.co.kr/@chihe2002/2
# https://brunch.co.kr/@chihe2002/3
# https://brunch.co.kr/@chihe2002/4
# https://brunch.co.kr/@chihe2002/5
# https://brunch.co.kr/@chihe2002/6
# https://brunch.co.kr/@chihe2002/7
# https://brunch.co.kr/@chihe2002/8
# https://brunch.co.kr/@chihe2002/9
# https://brunch.co.kr/@chihe2002/10
# https://brunch.co.kr/@chihe2002/11
# https://brunch.co.kr/@chihe2002/12
# https://brunch.co.kr/@carson52/2
# https://brunch.co.kr/@carson52/3
# https://brunch.co.kr/@carson52/4
# https://brunch.co.kr/@carson52/5
# https://brunch.co.kr/@carson52/6
# https://brunch.co.kr/@carson52/7
# https://brunch.co.kr/@carson52/8
# https://brunch.co.kr/@carson52/9
# https://brunch.co.kr/@carson52/10
# https://brunch.co.kr/@carson52/11
# https://brunch.co.kr/@carson52/12
# https://brunch.co.kr/@doahfather/2
# https://brunch.co.kr/@doahfather/3
# https://brunch.co.kr/@doahfather/4
# https://brunch.co.kr/@doahfather/5
# https://brunch.co.kr/@doahfather/6
# ...

# %%
url = "https://brunch.co.kr/@rlrmadks/32"
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}

variables = {
    "":""
    ,"g":""
}
params = {
    "variables":variables
}
    
#rs = requests.get(url, headers=headers).json()
rs = requests.get(url, headers=headers)
bs = BeautifulSoup(rs.text, 'html.parser')

bs.select('h4')
# Out:
# []

# %%
imsi_array = []
for item in list(imsi_rs):
  item['conetent'] = re.sub('(<([^>]+)>)', '', item['content'])
  imsi_rs.append(item)

# %%
str_bs = str(bs)
#str(bs).strip("'<>()").replace('\'','\"')

# %%
articles_array = []
import re
for item in rs:
  item['content'] = re.sub('(<([^>]+)>)', '', item['content'])
  item['content'] = item['content'][:200]
  articles_array.append(item)

return dumps(articles_array)

item['content'] = re.sub('(<([^>]+)>)', '', item['content'])

imsi = str(bs).strip("[](){}<>\\\"\'").replace('.','\n')

# %%
re.sub('a-zA-z/:;<.+?>', '', imsi, 0).strip()
# Out:
# '<!DOCTYPE html>\n\n<html lang="ko" xmlns="http://www\nw3\norg/1999/xhtml">\n<head>\n<title>몬주익 성을 내려오다 만난 호안 미로</title>\n<meta charset="utf-8"/>\n<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="몬주익 성을 내려오다 만난 호안 미로" name="title"/>\n<meta content="always" name="referrer"/>\n<meta name="secureToken" value="hUv+xvwTQHH8k/DcKUN0zoLWjXKNl8yuWQI5xsdEMAR1WcosrfMTMlIBVRc/pmqn"/>\n<meta content="max-image-preview:large" name="robots"/>\n<meta content="- 바르셀로나 | 바르셀로나에서의 마지막 날이다\n 어젯밤 우리는 새벽 3시에 호스텔로 돌아왔다\n 자리에 누운 지 얼마 되지 않아서부터 계속 문을 여닫는 소리 때문에 선잠을 잤다\n 우리도 늦었는데 우리보다 더한 사람들이 있었나 보다\n 아침 아홉 시 반까지 누워 있어도 잔 것 같지 않고 피곤하다\n  샤워하고 내 사랑 bluebard에 가서 브런치 타임을 가졌다\n 커다란 요구르트" name="description"/>\n<meta content="Annie" property="article:author"/>\n<meta content="Annie" name="og:article:author"/>\n<meta content="Annie" name="byl"/>\n<meta content="article" property="og:type"/>\n<meta content="brunch" property="o
# ...

# %%
imsi = re.sub('[\\0-9a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》;:\{\}\_]+', '', str(bs))
imsi
# Out:
# '몬주익성을내려오다만난호안미로몬주익성을내려오다만난호안미로바르셀로나바르셀로나에서의마지막날이다어젯밤우리는새벽시에호스텔로돌아왔다자리에누운지얼마되지않아서부터계속문을여닫는소리때문에선잠을잤다우리도늦었는데우리보다더한사람들이있었나보다아침아홉시반까지누워있어도잔것같지않고피곤하다샤워하고내사랑에가서브런치타임을가졌다커다란요구르트몬주익성을내려오다만난호안미로바르셀로나바르셀로나에서의마지막날이다어젯밤우리는새벽시에호스텔로돌아왔다자리에누운지얼마되지않아서부터계속문을여닫는소리때문에선잠을잤다우리도늦었는데우리보다더한사람들이있었나보다아침아홉시반까지누워있어도잔것같지않고피곤하다샤워하고내사랑에가서브런치타임을가졌다커다란요구르트몬주익성을내려오다만난호안미로바르셀로나바르셀로나에서의마지막날이다어젯밤우리는새벽시에호스텔로돌아왔다자리에누운지얼마되지않아서부터계속문을여닫는소리때문에선잠을잤다우리도늦었는데우리보다더한사람들이있었나보다아침아홉시반까지누워있어도잔것같지않고피곤하다샤워하고내사랑에가서브런치타임을가졌다커다란요구르트브런치브런치바르셀로나몬주익성을내려오다만난호안미로\\바르셀로나에서의마지막날이다어젯밤우리는새벽시에호스텔로돌아왔다자리에누운지얼마되지않아서부터계속문을여닫는소리때문에선잠을잤다우리도늦었는데우리보다더한사람들이있었나보다아침아홉시반까지누워있어도잔것같지않고피곤하다샤워하고내사랑에가서브런치타임을가졌다커다란요구르트와샌드위치커피그리고살구타르트는테이크아웃했다좋은베이커리가분명하다늘자리가없고긴줄이서있는데오늘은나오다보니문밖에까지긴줄이서있다레기나와데이비드는나갈채비를마치고있었다난피곤해서쉬다가오후에나가겠다고했다호스텔뒤뜰의소파에담요를덮고앉아이것저것기록을하다가오후한시반넘어서야자리를털고일어났다몬주익성에가는거다페럴렐역에서내려푸니쿨라를타면된다고했는데지하철역에서나와아무리둘러봐도푸니쿨라를어디서타는지도무지알수가없었다헤매다가이사람저사람에게물었더니지하철역안에서탄다고했다이미나와버렸는데다시지하철표를끊고들어가니푸니쿨라를타는곳이나왔다푸니쿨라가뭔가했는데특정관광구간을짧게오가는작은셔틀기차같은것이었다푸니쿨라에서내려이번에는케이블카를타야했다케이블카에서내려다본풍경은무척새롭고근사했다특히가
# ...

# %%
try: #try parsing to dict
    dataform = str(response_json).strip("'<>() ").replace('\'', '\"')
    struct = json.loads(dataform)
  except:
    print repr(resonse_json)
    print sys.exc_info()

# %%
re_h = re.compile('[가-힣]')
bs.select('meta[content]')
# Out:
# [<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="몬주익 성을 내려오다 만난 호안 미로" name="title"/>,
#  <meta content="always" name="referrer"/>,
#  <meta content="max-image-preview:large" name="robots"/>,
#  <meta content="- 바르셀로나 | 바르셀로나에서의 마지막 날이다. 어젯밤 우리는 새벽 3시에 호스텔로 돌아왔다. 자리에 누운 지 얼마 되지 않아서부터 계속 문을 여닫는 소리 때문에 선잠을 잤다. 우리도 늦었는데 우리보다 더한 사람들이 있었나 보다. 아침 아홉 시 반까지 누워 있어도 잔 것 같지 않고 피곤하다.  샤워하고 내 사랑 bluebard에 가서 브런치 타임을 가졌다. 커다란 요구르트" name="description"/>,
#  <meta content="Annie" property="article:author"/>,
#  <meta content="Annie" name="og:article:author"/>,
#  <meta content="Annie" name="byl"/>,
#  <meta content="article" property="og:type"/>,
#  <meta content="brunch" property="og:site_name"/>,
#  <meta content="몬주익 성을 내려오다 만난 호안 미로" property="og:title"/>,
# ...

# %%
bs.select
# Out:
# <!DOCTYPE html>
#
# <html lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>몬주익 성을 내려오다 만난 호안 미로</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="몬주익 성을 내려오다 만난 호안 미로" name="title"/>
# <meta content="always" name="referrer"/>
# <meta name="secureToken" value="6TORvkLaRafDfw9+99A1IRgF3EgjI7VTzLg5IMg2dYJpkCLSIpPEaNi3UGUOTTJl"/>
# <meta content="max-image-preview:large" name="robots"/>
# <meta content="- 바르셀로나 | 바르셀로나에서의 마지막 날이다. 어젯밤 우리는 새벽 3시에 호스텔로 돌아왔다. 자리에 누운 지 얼마 되지 않아서부터 계속 문을 여닫는 소리 때문에 선잠을 잤다. 우리도 늦었는데 우리보다 더한 사람들이 있었나 보다. 아침 아홉 시 반까지 누워 있어도 잔 것 같지 않고 피곤하다.  샤워하고 내 사랑 bluebard에 가서 브런치 타임을 가졌다. 커다란 요구르트" name="description"/>
# <meta content="Annie" property="article:author"/>
# <meta content="Annie" name="og:article:author"/>
# <meta content="Annie" name="byl"/>
# <meta content="article" property="og:type"/>
# ...

# %%
#content_url = "https://brunch.co.kr/keyword/%EC%A7%80%EA%B5%AC%ED%95%9C%EB%B0%94%ED%80%B4_%EC%84%B8%EA%B3%84%EC%97%AC%ED%96%89"
content_headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
#try:
for q in profile_list:
  q = urllib.parse.quote(q)
  print(q)
  for g in range(2, 3):
    content_url = 'https://brunch.co.kr/@{}/{}'.format(q, g)
    '''variables = {
        "q":str(q)
        ,"g":g
    }
    params = {
    "variables":variables
    }'''
    print(content_url)

    rs = requests.get(content_url, headers=content_headers)
    bs = BeautifulSoup(rs.text, 'html.parser')

    time.sleep(random.uniform(2,4))

    h4 = bs.select('h4')
    print(h4)

"""    for x in range(0,2):
        str_h4 = h4[135].find_all(string=True)
        for y in str_h4:
            str_y = str(y).strip()
            str_y.replace(".", "\n")
            cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\\‘|\(\)\[\]\<\>`\'\{\}\(\)\'…》]', '', str_y)
            result.append(str_y)

            time.sleep(random.uniform(2,4))"""
# Out:
# dinggiriboram
# https://brunch.co.kr/@dinggiriboram/2
# []
# stayfolio
# https://brunch.co.kr/@stayfolio/2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-0cb49167a973> in <module>()
#      16     print(content_url)
#      17
# ---> 18     rs = requests.get(content_url, headers=content_headers)
#      19     bs = BeautifulSoup(rs.text, 'html.parser')
#      20
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...
