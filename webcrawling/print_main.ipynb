# %% [markdown]
# <a href="https://colab.research.google.com/github/2pterons/twigfarm/blob/main/webcrawling/print_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import requests
import json
from bs4 import BeautifulSoup

profile_list = []
result = []

profile_url = "https://api.brunch.co.kr/v1/top/keyword/group/38?publishTime=1632646210000&pickContentId="
profile_headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}

int_time = 1632646210000
str_time = "1632646210000"


for i in range(0, 2):
  variables = {
      "publishTime":str_time
      ,"pickContentId":None
  }
  params = {
      "variables":json.dumps(variables)
  }

  rs = requests.get(profile_url, params=params, headers=profile_headers)
  js = json.loads(rs.text)
  for j in range(0, 2):
    profileId = js['data']['articleList'][j]['article']['profileId']
    profile_list.append(profileId)

    #content_url = "https://brunch.co.kr/keyword/%EC%A7%80%EA%B5%AC%ED%95%9C%EB%B0%94%ED%80%B4_%EC%84%B8%EA%B3%84%EC%97%AC%ED%96%89"
    content_url = "https://brunch.co.kr/@{}/{}"
    content_headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
    #try:
    for g in range(1, 3):
      for q in profile_list:
        content_url = "https://brunch.co.kr/@{}/{}".format(q,g)
        '''variables = {
            "q":str(q)
            ,"g":g
        }
        params = {
        "variables":variables
        }'''

        rs = requests.get(content_url, headers=content_headers)
        bs = BeautifulSoup(rs.text, 'html.parser')

        h4 = bs.select('h4')
        for x in range(0,2):
            str_h4 = h4[135].find_all(string=True)
            for y in str_h4:
                str_y = str(y).strip()
                str_y.replace(".", "\n")
                cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\\‘|\(\)\[\]\<\>`\'\{\}\(\)\'…》]', '', str_y)
                result.append(str_y)

                time.sleep(random.uniform(2,4))
    #except:
      #print("")    

  int_time += 1
  str_time = str(int_time)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-f7df03f03052> in <module>()
#      49         h4 = bs.select('h4')
#      50         for x in range(0,2):
# ---> 51             str_h4 = h4[135].find_all(string=True)
#      52             for y in str_h4:
#      53                 str_y = str(y).strip()
#
# IndexError: list index out of range

# %%
result
# Out:
# []

# %%
url = "https://brunch.co.kr/@{}/{}"
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}

for i in profile_list:
    variables = {
        "q":str(i)
        ,"g":""
    }
    params = {
        "variables":variables
    }

    rs = requests.get(url, params=params, headers=headers)
    bs = BeautifulSoup(rs.text, 'html.parser')

    result = []
    h4 = bs.select('h4')
    for x in range(0, len(h4)):
        str_h4 = h4[x].find_all(string=True)
        for y in str_h4:
            str_y = str(y).strip()
            str_y.replace(".", "\n")
            cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\\‘|\(\)\[\]\<\>`\'\{\}\(\)\'…》]', '', str_y)
            result.append(str_y)
            #result.strip()

# %%
def startCrawling():
  url = "https://brunch.co.kr/@{}/{}"
  for q in profile_id:
    variables = {"q":x
                ,"g":y}
  params = {"variables":variables}
  headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
  rs = requests.get(url, params=params, headers=headers)

  h4 = bs.select('h4')
  for i in range(len(h4))
    h4[i].find_all(string=True)

# %%
result = []
h4 = bs.select('h4')

for i in range(len(h4)):
  str_h4 = h4[i].find_all(string=True)
  print(type(str_h4))
  result.append(str_h4)

#kkk = ".".replace(result, "\n")
#print(kkk)

# %%
import re
import json
import requests
from bs4 import BeautifulSoup

url = "https://brunch.co.kr"

variables = {"g":"1"}
params = {"variables":variables}
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}

rs = requests.get(url, params=params, headers=headers)
#js = json.loads(rs.text)
bs = BeautifulSoup(rs.text, 'html.parser')

#rs = requests.get(url, headers=headers)
#bs = BeautifulSoup(rs, 'html.parser')

# %%
result = []
h4 = bs.select('h4')
for x in range(0, len(h4)):
  str_h4 = h4[x].find_all(string=True)
  for y in str_h4:
    str_y = str(y).strip()
    str_y.replace(".", "\n")
    cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'{}()\'…》]', '', str_y)
    result.append(str_y)
    #result.strip()

# %%
result
# Out:
# ['',
#  '2천 년 전이던 BC 1세기',
#  '아우구스투스 황제 시대에 로마의 팔라티노 언덕을 둘러보던 청년이 있었다. 할리카르나소스의 디오니시오스라는 역사학자였다. 그는 고대 그리스에 있던 할리카르나소스 출신이었다. 이 도시는 지금은 터키의 보드룸으로 국적과 이름이 바뀐 곳이다. BC 5세기의 유명한 역사학자 헤로도투스도 이곳 출신이었다.',
#  '',
#  '디오니시오스라는 이름은 그리스에서 매우 흔했다. 그래서 후세 사람들은 같은 이름을 가진 다른 사람과 구별하기 위해 그를 할리카르나소스의',
#  '디오니시오',
#  '스라고 불렀다.',
#  '그는 젊었을 때 로마로 건너가 22년 동안 수사학을 가르치면서 동시에',
#  '라틴',
#  '어를 배웠다. 또 로마 곳곳을 돌아다니며 역사의 현장을 살펴보거나 각종 책을 수집하거나 많은 역사학자를 만났다. 그는 이렇게 해서 모은 자료로 『로마의 역사』라는 책을 썼다. 그가 주목받는 것은 다른 역사서에서는 찾아볼 수 없는 흥미로운 장면을 이 책에 소개했기 때문이다.',
#  '',
#  '‘로마를 건국하는 데 아무런 장벽도 남지 않게 됐다. 로물루스는 먼저 신에게 경배한 뒤 날을 정해 팔라티노 언덕에서 의례를 진행하기로 했다.',
#  '예정된 날이 밝았다.',
#  '로물루스는 우선 신에게 희생제물을 바쳤다. 다른 사람들에게도 형편에 맞춰 희생제물을 바치라고 했다. 이어 신의 조짐을 살폈는데 아주 좋다는 결과를 얻었다.',
#  '그는 사람들에게 천막 앞에 불을 피우게 한 뒤 불꽃을 뛰어넘으라고 했다. 몸을 청결하게 하는 데 필요한 절차라는 것이었다.',
# ...

# %%
kkk = bs.select('h4')

# %%
kkk[111].find_all(string=True)
# Out:
# []

# %%
#text = bs.select('.wrap_body ')

# %%
bs.select('.wrap_cover')

# %%
bs.select('h4')
# Out:
# [<h4 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}],"size":"h4"}'><br/></h4>,
#  <h4 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}],"size":"h4"}'><br/></h4>,
#  <h4 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"br"}],"size":"h4"}'><br/></h4>,
#  <h4 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"text","data":[{"type":"text","text":" "}],"styleType":"bold"}],"size":"h4"}'><b> </b></h4>,
# ...

# %%
bs.select('.wrap_item')

# %%
bs.h4.find_all(string=True)
# Out:
# []

# %%
bs.select('h4')[134].find_all(string=True)
# Out:
# ['\xa0“네 궁금증을 풀어주려고 독수리가 하늘로 날아오르는구나!”\xa0']

# %%
bs.select('h4')[135].find_all(string=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-952a39e64732> in <module>()
# ----> 1 bs.select('h4')[135].find_all(string=True).strip()
#
# /usr/local/lib/python3.7/dist-packages/bs4/element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'strip'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
for i in bs

# %%
bs.select('h4')[134]
# Out:
# <h4 class="wrap_item item_type_text" data-app='{"type":"text","data":[{"type":"text","style":{"color":"#00c3bd"},"data":[{"type":"text","text":" “네 궁금증을 풀어주려고 독수리가 하늘로 날아오르는구나!” "}]}],"size":"h4"}'><span style="color:#00c3bd;"> “네 궁금증을 풀어주려고 독수리가 하늘로 날아오르는구나!” </span></h4>

# %%
bs.select('h4')[134]['data-app']

# %%
import re

# %%
import re

cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'{}()\'…》]', '', text)
cleaned_text.strip()
cleaned_text

# %%
result = []
text = bs.select('span')

for i in text:
  #imsi = bs.select('.wrap_body .wrap_item')[i]['data-app']
  list(i)
  for j in i:
    print(type(j))
    #cleaned_text = re.sub('[a-zA-Z-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'{}()\'…》]', '', j)
    #cleaned_text.strip()
    #result.append(cleaned_text)

# %%
text[0]
# Out:
# <span class="f_l text_hide img_ico img_ico_with_text ico_likeit_like #like">라이킷</span>

# %%
text
